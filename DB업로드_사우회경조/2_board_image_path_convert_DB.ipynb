# %%
# 이미지 경로 변환 - DB 직접 연동 버전
# type 컬럼으로 게시판 선택

import json
import os
import shutil
import re
from pathlib import Path
import pymysql
from sqlalchemy import create_engine

# ==================== DB 설정 ====================
USER = "root"
PASS = "1234"
HOST = "127.0.0.1"
PORT = 3306
DB = "crawling"

# ==================== 설정 영역 (여기를 수정하세요) ====================

# 게시판 타입 (필터링용)
BOARD_TYPE = "event"  # ✨ 추가: hredu, cp, sales 등

# 이미지 원본 경로들 - 여러 경로 추가 가능
BASE_IMAGE_PATHS = [
    r"C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor",
    r"C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\daumeditor",
    r"C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\namoeditor",
    r"C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor",
    # 더 추가하고 싶으면 여기에 계속 추가
]

# 이미지 복사본 저장 폴더 (타입별로 자동 생성)
OUTPUT_IMAGE_FOLDER = rf"C:\Users\LEEJUHWAN\Downloads\board_{BOARD_TYPE}_img"  # ✨ 타입 반영

# src에서 제거할 접두사 (이 부분을 제거하고 상대경로로 변경)
REMOVE_PREFIX = r"C:\Users\LEEJUHWAN\Downloads"

# ======================================================================


def find_image_folder(folder_name):
    """여러 경로에서 이미지 폴더 찾기"""
    for base_path in BASE_IMAGE_PATHS:
        image_folder = Path(base_path) / folder_name
        if image_folder.exists():
            return image_folder
    return None


def process_single_post(data, post_index):
    """하나의 post 데이터 처리"""
    
    # sourceId에서 문서ID 추출
    source_id = data.get('sourceId', '')
    if not source_id:
        print(f"⚠️ [{post_index}] sourceId 없음, 건너뜀")
        return data  # 원본 그대로 반환
    
    doc_id = source_id.lstrip('_')
    folder_name = f"brd{doc_id}"
    
    # 여러 경로에서 이미지 폴더 찾기
    image_folder = find_image_folder(folder_name)
    
    if not image_folder:
        print(f"⚠️ [{post_index}] 폴더 없음: {folder_name} (모든 경로 검색 완료)")
        return data  # 원본 그대로 반환
    
    # 복사본 저장할 문서별 폴더 생성
    output_doc_folder = Path(OUTPUT_IMAGE_FOLDER) / folder_name
    output_doc_folder.mkdir(parents=True, exist_ok=True)
    
    print(f"\n📄 [{post_index}] 문서ID: {doc_id}")
    print(f"   원본: {image_folder}")
    print(f"   복사: {output_doc_folder}")
    
    # HTML에서 img 태그 찾기
    html_content = data.get('content', '')
    if not html_content:
        print(f"   ⚠️ content 없음")
        return data
    
    img_pattern = r'<img[^>]+src="([^"]+)"[^>]*>'
    img_matches = list(re.finditer(img_pattern, html_content))
    
    if not img_matches:
        print(f"   ℹ️ 이미지 없음")
        return data
    
    print(f"   ✅ 이미지 {len(img_matches)}개 발견")
    
    # 파일 복사 & src 경로 변경
    new_html = html_content
    copied_count = 0
    
    for idx, match in enumerate(img_matches):
        old_src = match.group(1)
        
        # 원본 파일 (0, 1, 2...)
        old_file = image_folder / str(idx)
        
        # 복사본 파일 (.jpg 확장자 추가)
        new_file = output_doc_folder / f"{idx}.jpg"
        
        # 파일 복사
        if old_file.exists():
            shutil.copy2(old_file, new_file)
            copied_count += 1
            print(f"      ✅ {old_file.name} → {new_file.name}")
            
            # src 경로 변경 (상대경로로)
            new_src = str(new_file).replace('\\', '/')
            if REMOVE_PREFIX:
                prefix_with_slash = REMOVE_PREFIX.replace('\\', '/')
                if new_src.startswith(prefix_with_slash):
                    new_src = new_src[len(prefix_with_slash):].lstrip('/')
            
            new_html = new_html.replace(old_src, new_src, 1)
        else:
            print(f"      ⚠️ 파일 없음: {old_file.name} - src 공란 처리")
            # src를 빈 문자열로 변경
            new_html = new_html.replace(old_src, '', 1)
    
    print(f"   📊 복사 완료: {copied_count}/{len(img_matches)}개")
    
    # 수정된 HTML 적용
    data['content'] = new_html
    return data


def process_db(board_type):
    """DB에서 특정 type의 데이터만 읽고 처리 후 DB에 업데이트"""
    
    # 출력 폴더 생성
    os.makedirs(OUTPUT_IMAGE_FOLDER, exist_ok=True)
    
    # DB 연결
    print(f"📂 DB 연결 중...")
    print(f"📂 게시판 타입: {board_type}")  # ✨ 추가
    print(f"📂 검색할 이미지 경로: {len(BASE_IMAGE_PATHS)}개\n")
    
    connection = pymysql.connect(
        host=HOST,
        user=USER,
        password=PASS,
        database=DB,
        port=PORT,
        charset='utf8mb4'
    )
    
    try:
        with connection.cursor(pymysql.cursors.DictCursor) as cursor:
            # 1. DB에서 특정 type의 데이터만 읽기
            query = "SELECT * FROM board_posts WHERE type = %s"  # ✨ WHERE 조건 추가
            cursor.execute(query, (board_type,))
            posts = cursor.fetchall()
            
            total_count = len(posts)
            print(f"✅ 총 {total_count}개의 posts 발견\n")
            
            # 2. 각 post 처리
            processed_count = 0
            
            for idx, post in enumerate(posts, 1):
                try:
                    # 원본 content 저장 (비교용)
                    original_content = post.get('content', '')
                    
                    # attaches_json을 파싱하여 attaches로 변환
                    if post.get('attaches_json'):
                        post['attaches'] = json.loads(post['attaches_json'])
                    else:
                        post['attaches'] = []
                    
                    # 기존 로직 그대로 사용
                    result = process_single_post(post, idx)
                    
                    # content가 변경된 경우만 DB 업데이트
                    if result['content'] != original_content:
                        update_query = """
                            UPDATE board_posts 
                            SET content = %s 
                            WHERE sourceId = %s AND type = %s
                        """  # ✨ WHERE 조건에 type도 추가
                        cursor.execute(update_query, (result['content'], result['sourceId'], board_type))
                        processed_count += 1
                    
                except Exception as e:
                    print(f"❌ [Post {idx}] 처리 오류: {e}")
                    continue
            
            # 변경사항 커밋
            connection.commit()
            
            print(f"\n{'='*60}")
            print(f"✅ 처리 완료!")
            print(f"   - 게시판 타입: {board_type}")  # ✨ 추가
            print(f"   - 처리된 posts: {processed_count}/{total_count}개")
            print(f"   - 복사된 이미지 위치: {OUTPUT_IMAGE_FOLDER}")
            print(f"   - DB 테이블: board_posts (content 컬럼 업데이트)")
            print(f"{'='*60}")
    
    finally:
        connection.close()
        print("\n✅ DB 연결 종료")


# 실행
if __name__ == "__main__":
    process_db(BOARD_TYPE)  # ✨ board_type 인자 추가
# Out:
# 📂 DB 연결 중...
# 📂 게시판 타입: event
# 📂 검색할 이미지 경로: 4개
#
# ✅ 총 309개의 posts 발견
#
# ⚠️ [1] 폴더 없음: brd4098793 (모든 경로 검색 완료)
# ⚠️ [2] 폴더 없음: brd4087362 (모든 경로 검색 완료)
# ⚠️ [3] 폴더 없음: brd4073932 (모든 경로 검색 완료)
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2282810
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd2282810
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [143] 문서ID: 2279017
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2279017
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd2279017
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ⚠️ 파일 없음: 1 - src 공란 처리
#    📊 복사 완료: 1/2개
#
# 📄 [144] 문서ID: 2263052
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2263052
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd2263052
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [145] 문서ID: 2258872
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2258872
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd2258872
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [146] 문서ID: 2242236
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2242236
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd2242236
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [147] 문서ID: 2224862
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2224862
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd2224862
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [148] 문서ID: 2203915
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2203915
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd2203915
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [149] 문서ID: 2184829
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2184829
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd2184829
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [150] 문서ID: 2168434
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2168434
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd2168434
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ⚠️ 파일 없음: 1 - src 공란 처리
#    📊 복사 완료: 1/2개
#
# 📄 [151] 문서ID: 2167605
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2167605
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd2167605
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [152] 문서ID: 2149964
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2149964
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd2149964
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [153] 문서ID: 2097388
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2097388
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd2097388
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [154] 문서ID: 2031708
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2031708
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd2031708
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [155] 문서ID: 2015588
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2015588
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd2015588
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [156] 문서ID: 2010330
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2010330
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd2010330
#    ✅ 이미지 3개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#    📊 복사 완료: 3/3개
#
# 📄 [157] 문서ID: 1995314
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd1995314
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd1995314
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [158] 문서ID: 1929655
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd1929655
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd1929655
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [159] 문서ID: 994836
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd994836
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd994836
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [160] 문서ID: 993876
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd993876
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd993876
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [161] 문서ID: 991838
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd991838
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd991838
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
#
# 📄 [162] 문서ID: 982036
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd982036
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd982036
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [163] 문서ID: 977446
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd977446
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd977446
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [164] 문서ID: 970832
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd970832
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd970832
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [165] 문서ID: 960058
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd960058
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd960058
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [166] 문서ID: 959847
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd959847
#    복사: C:\Users\LEEJUHWAN\Downloads\board_event_img\brd959847
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [167] 폴더 없음: brd865623 (모든 경로 검색 완료)
# ⚠️ [168] 폴더 없음: brd865615 (모든 경로 검색 완료)
# ⚠️ [169] 폴더 없음: brd865613 (모든 경로 검색 완료)
# ⚠️ [170] 폴더 없음: brd865603 (모든 경로 검색 완료)
# ⚠️ [171] 폴더 없음: brd865602 (모든 경로 검색 완료)
# ⚠️ [172] 폴더 없음: brd865593 (모든 경로 검색 완료)
# ⚠️ [173] 폴더 없음: brd865592 (모든 경로 검색 완료)
# ⚠️ [174] 폴더 없음: brd865584 (모든 경로 검색 완료)
# ⚠️ [175] 폴더 없음: brd865582 (모든 경로 검색 완료)
# ⚠️ [176] 폴더 없음: brd865571 (모든 경로 검색 완료)
# ⚠️ [177] 폴더 없음: brd865568 (모든 경로 검색 완료)
# ⚠️ [178] 폴더 없음: brd865564 (모든 경로 검색 완료)
# ⚠️ [179] 폴더 없음: brd865550 (모든 경로 검색 완료)
# ⚠️ [180] 폴더 없음: brd865544 (모든 경로 검색 완료)
# ⚠️ [181] 폴더 없음: brd865542 (모든 경로 검색 완료)
# ⚠️ [182] 폴더 없음: brd865537 (모든 경로 검색 완료)
# ⚠️ [183] 폴더 없음: brd865536 (모든 경로 검색 완료)
# ⚠️ [184] 폴더 없음: brd865535 (모든 경로 검색 완료)
# ⚠️ [185] 폴더 없음: brd865528 (모든 경로 검색 완료)
# ⚠️ [186] 폴더 없음: brd865527 (모든 경로 검색 완료)
# ⚠️ [187] 폴더 없음: brd865511 (모든 경로 검색 완료)
# ⚠️ [188] 폴더 없음: brd865491 (모든 경로 검색 완료)
# ⚠️ [189] 폴더 없음: brd865488 (모든 경로 검색 완료)
# ⚠️ [190] 폴더 없음: brd865465 (모든 경로 검색 완료)
# ⚠️ [191] 폴더 없음: brd865458 (모든 경로 검색 완료)
# ⚠️ [192] 폴더 없음: brd865452 (모든 경로 검색 완료)
# ⚠️ [193] 폴더 없음: brd865440 (모든 경로 검색 완료)
# ⚠️ [194] 폴더 없음: brd865438 (모든 경로 검색 완료)
# ⚠️ [195] 폴더 없음: brd865428 (모든 경로 검색 완료)
# ⚠️ [196] 폴더 없음: brd865424 (모든 경로 검색 완료)
# ⚠️ [197] 폴더 없음: brd865411 (모든 경로 검색 완료)
# ⚠️ [198] 폴더 없음: brd865398 (모든 경로 검색 완료)
# ⚠️ [199] 폴더 없음: brd865365 (모든 경로 검색 완료)
# ⚠️ [200] 폴더 없음: brd865364 (모든 경로 검색 완료)
# ⚠️ [201] 폴더 없음: brd865363 (모든 경로 검색 완료)
# ⚠️ [202] 폴더 없음: brd865361 (모든 경로 검색 완료)
# ⚠️ [203] 폴더 없음: brd865360 (모든 경로 검색 완료)
# ⚠️ [204] 폴더 없음: brd865352 (모든 경로 검색 완료)
# ⚠️ [205] 폴더 없음: brd865287 (모든 경로 검색 완료)
# ⚠️ [206] 폴더 없음: brd865279 (모든 경로 검색 완료)
# ⚠️ [207] 폴더 없음: brd865273 (모든 경로 검색 완료)
# ⚠️ [208] 폴더 없음: brd865244 (모든 경로 검색 완료)
# ⚠️ [209] 폴더 없음: brd865223 (모든 경로 검색 완료)
# ⚠️ [210] 폴더 없음: brd865221 (모든 경로 검색 완료)
# ⚠️ [211] 폴더 없음: brd865208 (모든 경로 검색 완료)
# ⚠️ [212] 폴더 없음: brd865204 (모든 경로 검색 완료)
# ⚠️ [213] 폴더 없음: brd865200 (모든 경로 검색 완료)
# ⚠️ [214] 폴더 없음: brd865187 (모든 경로 검색 완료)
# ⚠️ [215] 폴더 없음: brd865185 (모든 경로 검색 완료)
# ⚠️ [216] 폴더 없음: brd865159 (모든 경로 검색 완료)
# ⚠️ [217] 폴더 없음: brd865142 (모든 경로 검색 완료)
# ⚠️ [218] 폴더 없음: brd865139 (모든 경로 검색 완료)
# ⚠️ [219] 폴더 없음: brd865120 (모든 경로 검색 완료)
# ⚠️ [220] 폴더 없음: brd865113 (모든 경로 검색 완료)
# ⚠️ [221] 폴더 없음: brd865099 (모든 경로 검색 완료)
# ⚠️ [222] 폴더 없음: brd865087 (모든 경로 검색 완료)
# ⚠️ [223] 폴더 없음: brd865081 (모든 경로 검색 완료)
# ⚠️ [224] 폴더 없음: brd865066 (모든 경로 검색 완료)
# ⚠️ [225] 폴더 없음: brd865065 (모든 경로 검색 완료)
# ⚠️ [226] 폴더 없음: brd865063 (모든 경로 검색 완료)
# ⚠️ [227] 폴더 없음: brd865056 (모든 경로 검색 완료)
# ⚠️ [228] 폴더 없음: brd865029 (모든 경로 검색 완료)
# ⚠️ [229] 폴더 없음: brd865020 (모든 경로 검색 완료)
# ⚠️ [230] 폴더 없음: brd865015 (모든 경로 검색 완료)
# ⚠️ [231] 폴더 없음: brd864981 (모든 경로 검색 완료)
# ⚠️ [232] 폴더 없음: brd864975 (모든 경로 검색 완료)
# ⚠️ [233] 폴더 없음: brd864960 (모든 경로 검색 완료)
# ⚠️ [234] 폴더 없음: brd864955 (모든 경로 검색 완료)
# ⚠️ [235] 폴더 없음: brd864941 (모든 경로 검색 완료)
# ⚠️ [236] 폴더 없음: brd864929 (모든 경로 검색 완료)
# ⚠️ [237] 폴더 없음: brd864914 (모든 경로 검색 완료)
# ⚠️ [238] 폴더 없음: brd864912 (모든 경로 검색 완료)
# ⚠️ [239] 폴더 없음: brd864896 (모든 경로 검색 완료)
# ⚠️ [240] 폴더 없음: brd864893 (모든 경로 검색 완료)
# ⚠️ [241] 폴더 없음: brd864891 (모든 경로 검색 완료)
# ⚠️ [242] 폴더 없음: brd864857 (모든 경로 검색 완료)
# ⚠️ [243] 폴더 없음: brd864846 (모든 경로 검색 완료)
# ⚠️ [244] 폴더 없음: brd864827 (모든 경로 검색 완료)
# ⚠️ [245] 폴더 없음: brd864810 (모든 경로 검색 완료)
# ⚠️ [246] 폴더 없음: brd864782 (모든 경로 검색 완료)
# ⚠️ [247] 폴더 없음: brd864777 (모든 경로 검색 완료)
# ⚠️ [248] 폴더 없음: brd864776 (모든 경로 검색 완료)
# ⚠️ [249] 폴더 없음: brd864773 (모든 경로 검색 완료)
# ⚠️ [250] 폴더 없음: brd864772 (모든 경로 검색 완료)
# ⚠️ [251] 폴더 없음: brd864762 (모든 경로 검색 완료)
# ⚠️ [252] 폴더 없음: brd864747 (모든 경로 검색 완료)
# ⚠️ [253] 폴더 없음: brd864745 (모든 경로 검색 완료)
# ⚠️ [254] 폴더 없음: brd864729 (모든 경로 검색 완료)
# ⚠️ [255] 폴더 없음: brd864722 (모든 경로 검색 완료)
# ⚠️ [256] 폴더 없음: brd864720 (모든 경로 검색 완료)
# ⚠️ [257] 폴더 없음: brd864715 (모든 경로 검색 완료)
# ⚠️ [258] 폴더 없음: brd864698 (모든 경로 검색 완료)
# ⚠️ [259] 폴더 없음: brd864671 (모든 경로 검색 완료)
# ⚠️ [260] 폴더 없음: brd864670 (모든 경로 검색 완료)
# ⚠️ [261] 폴더 없음: brd864653 (모든 경로 검색 완료)
# ⚠️ [262] 폴더 없음: brd864633 (모든 경로 검색 완료)
# ⚠️ [263] 폴더 없음: brd864620 (모든 경로 검색 완료)
# ⚠️ [264] 폴더 없음: brd864570 (모든 경로 검색 완료)
# ⚠️ [265] 폴더 없음: brd864549 (모든 경로 검색 완료)
# ⚠️ [266] 폴더 없음: brd864533 (모든 경로 검색 완료)
# ⚠️ [267] 폴더 없음: brd864482 (모든 경로 검색 완료)
# ⚠️ [268] 폴더 없음: brd864436 (모든 경로 검색 완료)
# ⚠️ [269] 폴더 없음: brd864433 (모든 경로 검색 완료)
# ⚠️ [270] 폴더 없음: brd864416 (모든 경로 검색 완료)
# ⚠️ [271] 폴더 없음: brd864410 (모든 경로 검색 완료)
# ⚠️ [272] 폴더 없음: brd864400 (모든 경로 검색 완료)
# ⚠️ [273] 폴더 없음: brd864395 (모든 경로 검색 완료)
# ⚠️ [274] 폴더 없음: brd864353 (모든 경로 검색 완료)
# ⚠️ [275] 폴더 없음: brd864349 (모든 경로 검색 완료)
# ⚠️ [276] 폴더 없음: brd864292 (모든 경로 검색 완료)
# ⚠️ [277] 폴더 없음: brd864271 (모든 경로 검색 완료)
# ⚠️ [278] 폴더 없음: brd864264 (모든 경로 검색 완료)
# ⚠️ [279] 폴더 없음: brd864222 (모든 경로 검색 완료)
# ⚠️ [280] 폴더 없음: brd864221 (모든 경로 검색 완료)
# ⚠️ [281] 폴더 없음: brd864219 (모든 경로 검색 완료)
# ⚠️ [282] 폴더 없음: brd864173 (모든 경로 검색 완료)
# ⚠️ [283] 폴더 없음: brd864102 (모든 경로 검색 완료)
# ⚠️ [284] 폴더 없음: brd864092 (모든 경로 검색 완료)
# ⚠️ [285] 폴더 없음: brd864079 (모든 경로 검색 완료)
# ⚠️ [286] 폴더 없음: brd864077 (모든 경로 검색 완료)
# ⚠️ [287] 폴더 없음: brd864054 (모든 경로 검색 완료)
# ⚠️ [288] 폴더 없음: brd863958 (모든 경로 검색 완료)
# ⚠️ [289] 폴더 없음: brd863928 (모든 경로 검색 완료)
# ⚠️ [290] 폴더 없음: brd863912 (모든 경로 검색 완료)
# ⚠️ [291] 폴더 없음: brd863849 (모든 경로 검색 완료)
# ⚠️ [292] 폴더 없음: brd863846 (모든 경로 검색 완료)
# ⚠️ [293] 폴더 없음: brd863844 (모든 경로 검색 완료)
# ⚠️ [294] 폴더 없음: brd863842 (모든 경로 검색 완료)
# ⚠️ [295] 폴더 없음: brd863840 (모든 경로 검색 완료)
# ⚠️ [296] 폴더 없음: brd863836 (모든 경로 검색 완료)
# ⚠️ [297] 폴더 없음: brd863810 (모든 경로 검색 완료)
# ⚠️ [298] 폴더 없음: brd863799 (모든 경로 검색 완료)
# ⚠️ [299] 폴더 없음: brd863692 (모든 경로 검색 완료)
# ⚠️ [300] 폴더 없음: brd862994 (모든 경로 검색 완료)
# ⚠️ [301] 폴더 없음: brd862993 (모든 경로 검색 완료)
# ⚠️ [302] 폴더 없음: brd862992 (모든 경로 검색 완료)
# ⚠️ [303] 폴더 없음: brd862991 (모든 경로 검색 완료)
# ⚠️ [304] 폴더 없음: brd862990 (모든 경로 검색 완료)
# ⚠️ [305] 폴더 없음: brd862989 (모든 경로 검색 완료)
# ⚠️ [306] 폴더 없음: brd862988 (모든 경로 검색 완료)
# ⚠️ [307] 폴더 없음: brd862987 (모든 경로 검색 완료)
# ⚠️ [308] 폴더 없음: brd862986 (모든 경로 검색 완료)
# ⚠️ [309] 폴더 없음: brd862985 (모든 경로 검색 완료)
#
# ============================================================
# ✅ 처리 완료!
#    - 게시판 타입: event
#    - 처리된 posts: 126/309개
#    - 복사된 이미지 위치: C:\Users\LEEJUHWAN\Downloads\board_event_img
#    - DB 테이블: board_posts (content 컬럼 업데이트)
# ============================================================
#
# ✅ DB 연결 종료

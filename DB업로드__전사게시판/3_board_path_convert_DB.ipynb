# %%
# 첨부파일 경로 변환 - DB 직접 연동 버전
# type 컬럼으로 게시판 선택

import json
import os
import shutil
from pathlib import Path
import pymysql
from sqlalchemy import create_engine

# ==================== DB 설정 ====================
USER = "root"
PASS = "1234"
HOST = "127.0.0.1"
PORT = 3306
DB = "crawling"

# ==================== 설정 영역 (여기를 수정하세요) ====================

# 게시판 타입 (필터링용)
BOARD_TYPE = "biz"  # ✨ 추가: hredu, cp, sales 등

# 첨부파일 원본 경로들 - 여러 경로 추가 가능
BASE_FILE_PATHS = [
    r"C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd",
    r"C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd",
    r"C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd",
    r"C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd",
    # 더 추가하고 싶으면 여기에 계속 추가
]

# 첨부파일 복사본 저장 폴더 (타입별로 자동 생성)
OUTPUT_FILE_FOLDER = rf"C:\Users\LEEJUHWAN\Downloads\board_{BOARD_TYPE}_attachments"  # ✨ 타입 반영

# path에서 제거할 접두사 (이 부분을 제거하고 상대경로로 변경)
REMOVE_PREFIX = r"C:\Users\LEEJUHWAN\Downloads"

# ======================================================================


def find_attachment_folder(board_id):
    """여러 경로에서 첨부파일 폴더 찾기"""
    for base_path in BASE_FILE_PATHS:
        attachment_folder = Path(base_path) / board_id
        if attachment_folder.exists():
            return attachment_folder
    return None


def find_file_in_folder(folder, filename):
    """폴더 내에서 파일명과 일치하는 파일 찾기 (대소문자 구분 없음)"""
    if not folder or not folder.exists():
        return None
    
    # 정확한 파일명으로 먼저 찾기
    target_file = folder / filename
    if target_file.exists() and target_file.is_file():
        return target_file
    
    # 대소문자 구분 없이 찾기
    for file in folder.iterdir():
        if file.is_file() and file.name.lower() == filename.lower():
            return file
    
    return None


def process_single_post_attachments(data, post_index):
    """하나의 post의 첨부파일 처리"""
    
    # sourceId에서 게시판ID 추출
    source_id = data.get('sourceId', '')
    if not source_id:
        print(f"⚠️ [{post_index}] sourceId 없음, 건너뜀")
        return data
    
    board_id = source_id.lstrip('_')
    
    # attaches 배열 확인
    attaches = data.get('attaches', [])
    if not attaches:
        return data  # 첨부파일 없으면 그대로 반환
    
    # 여러 경로에서 첨부파일 폴더 찾기
    attachment_folder = find_attachment_folder(board_id)
    
    if not attachment_folder:
        print(f"⚠️ [{post_index}] 게시판ID {board_id} 폴더 없음 (모든 경로 검색 완료)")
        # 폴더가 없으면 모든 첨부파일의 path를 공란으로
        for attach in attaches:
            attach['path'] = ''
        return data
    
    # 복사본 저장할 게시판별 폴더 생성
    output_board_folder = Path(OUTPUT_FILE_FOLDER) / f"brd{board_id}"
    output_board_folder.mkdir(parents=True, exist_ok=True)
    
    print(f"\n📄 [{post_index}] 게시판ID: {board_id}")
    print(f"   원본: {attachment_folder}")
    print(f"   복사: {output_board_folder}")
    print(f"   ✅ 첨부파일 {len(attaches)}개 발견")
    
    # 각 첨부파일 처리
    processed_attaches = []
    copied_count = 0
    
    for idx, attach in enumerate(attaches):
        filename = attach.get('name', '')
        if not filename:
            print(f"      ⚠️ [{idx}] 파일명 없음 - path 공란 처리")
            attach['path'] = ''
            processed_attaches.append(attach)
            continue
        
        # 원본 폴더에서 파일 찾기
        source_file = find_file_in_folder(attachment_folder, filename)
        
        if source_file:
            # 복사본 파일 경로
            dest_file = output_board_folder / filename
            
            # 파일 복사
            try:
                shutil.copy2(source_file, dest_file)
                copied_count += 1
                print(f"      ✅ {filename}")
                
                # path를 상대경로로 변경 (REMOVE_PREFIX 제거)
                new_path = str(dest_file).replace('\\', '/')
                if REMOVE_PREFIX:
                    new_path = new_path.replace(REMOVE_PREFIX.replace('\\', '/'), '').lstrip('/')
                    new_path = new_path.replace(REMOVE_PREFIX, '').lstrip('\\')
                
                attach['path'] = new_path
                
            except Exception as e:
                print(f"      ❌ {filename} 복사 실패: {e}")
                attach['path'] = ''
        else:
            print(f"      ⚠️ 파일 없음: {filename} - path 공란 처리")
            attach['path'] = ''
        
        processed_attaches.append(attach)
    
    print(f"   📊 복사 완료: {copied_count}/{len(attaches)}개")
    
    # 수정된 attaches 적용
    data['attaches'] = processed_attaches
    return data


def process_db(board_type):
    """DB에서 특정 type의 데이터만 읽고 처리 후 DB에 업데이트"""
    
    # 출력 폴더 생성
    os.makedirs(OUTPUT_FILE_FOLDER, exist_ok=True)
    
    # DB 연결
    print(f"📂 DB 연결 중...")
    print(f"📂 게시판 타입: {board_type}")  # ✨ 추가
    print(f"📂 검색할 첨부파일 경로: {len(BASE_FILE_PATHS)}개\n")
    
    connection = pymysql.connect(
        host=HOST,
        user=USER,
        password=PASS,
        database=DB,
        port=PORT,
        charset='utf8mb4'
    )
    
    try:
        with connection.cursor(pymysql.cursors.DictCursor) as cursor:
            # 1. DB에서 특정 type의 데이터만 읽기
            query = "SELECT * FROM board_posts WHERE type = %s"  # ✨ WHERE 조건 추가
            cursor.execute(query, (board_type,))
            posts = cursor.fetchall()
            
            total_count = len(posts)
            print(f"✅ 총 {total_count}개의 posts 발견\n")
            
            # 2. 각 post 처리
            success_count = 0
            total_attachments = 0
            
            for idx, post in enumerate(posts, 1):
                try:
                    # attaches_json을 파싱하여 attaches로 변환
                    if post.get('attaches_json'):
                        post['attaches'] = json.loads(post['attaches_json'])
                    else:
                        post['attaches'] = []
                    
                    # 첨부파일이 있는 경우만 카운트
                    if post.get('attaches'):
                        total_attachments += len(post.get('attaches'))
                    
                    # 기존 로직 그대로 사용
                    result = process_single_post_attachments(post, idx)
                    
                    # attaches가 변경된 경우 DB 업데이트
                    if result.get('attaches'):
                        # attaches를 JSON 문자열로 변환
                        attaches_json = json.dumps(result['attaches'], ensure_ascii=False)
                        
                        update_query = """
                            UPDATE board_posts 
                            SET attaches_json = %s 
                            WHERE sourceId = %s AND type = %s
                        """  # ✨ WHERE 조건에 type도 추가
                        cursor.execute(update_query, (attaches_json, result['sourceId'], board_type))
                        success_count += 1
                    
                except Exception as e:
                    print(f"❌ [Post {idx}] 처리 오류: {e}")
                    continue
            
            # 변경사항 커밋
            connection.commit()
            
            print(f"\n{'='*60}")
            print(f"✅ 처리 완료!")
            print(f"   - 게시판 타입: {board_type}")  # ✨ 추가
            print(f"   - 첨부파일 있는 posts: {success_count}개")
            print(f"   - 총 첨부파일 개수: {total_attachments}개")
            print(f"   - 복사된 파일 위치: {OUTPUT_FILE_FOLDER}")
            print(f"   - DB 테이블: board_posts (attaches_json 컬럼 업데이트)")
            print(f"{'='*60}")
    
    finally:
        connection.close()
        print("\n✅ DB 연결 종료")


# 실행
if __name__ == "__main__":
    process_db(BOARD_TYPE)  # ✨ board_type 인자 추가
# Out:
# 📂 DB 연결 중...
# 📂 게시판 타입: biz
# 📂 검색할 첨부파일 경로: 4개
#
# ✅ 총 1750개의 posts 발견
#
#
# 📄 [9] 게시판ID: 4093565
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\4093565
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd4093565
#    ✅ 첨부파일 1개 발견
#       ✅ 본사 및 기술센터_자리배치도.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [17] 게시판ID: 4082289
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\4082289
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd4082289
#    ✅ 첨부파일 1개 발견
#       ✅ AI연구소설립계획_CTO(20250915).pdf
#    📊 복사 완료: 1/1개
#
# 📄 [23] 게시판ID: 4065984
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\4065984
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd4065984
#    ✅ 첨부파일 1개 발견
#       ✅ 본사 및 기술센터_자리배치도.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [44] 게시판ID: 4022767
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\4022767
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd4022767
#    ✅ 첨부파일 1개 발견
#       ✅ 본사 및 기술센터_자리배치도.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [46] 게시판ID: 4016228
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\4016228
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd4016228
#    ✅ 첨부파일 3개 발견
#       ✅ 2025년 네이버 파트너 임직원 건강검진 프로그램_배포용_v1.0.xlsx
#       ✅ (붙임2) 용인세브란스병원 2025년도 건강검진 안내문.pdf
#       ✅ (붙임1) 한국의학연구소KMI_온라인예약_이용가이드.pdf
#    📊 복사 완료: 3/3개
#
# 📄 [50] 게시판ID: 4013048
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\4013048
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd4013048
#    ✅ 첨부파일 1개 발견
#       ✅ 2025 월드IT쇼 전시회_애니파이브.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [71] 게시판ID: 3976346
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3976346
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3976346
#    ✅ 첨부파일 1개 발견
#       ✅ 2025 전사코드체계_20250211.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [72] 게시판ID: 3975973
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3975973
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3975973
#    ✅ 첨부파일 1개 발견
#       ✅ 본사 및 기술센터_자리배치도.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [78] 게시판ID: 3965703
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3965703
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3965703
#    ✅ 첨부파일 2개 발견
#       ✅ 2024년 귀속 연말정산 개정세법 요약.hwp
#       ✅ 2024년 근로자를 위한 신고 안내.pdf
#    📊 복사 완료: 2/2개
#
# 📄 [114] 게시판ID: 3878699
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3878699
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3878699
#    ✅ 첨부파일 1개 발견
#       ✅ (양식)과제및사업추진_계획서_20240801.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [126] 게시판ID: 3852444
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3852444
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3852444
#    ✅ 첨부파일 1개 발견
#       ✅ 본사 및 기술센터_자리배치도.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [159] 게시판ID: 3795270
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3795270
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3795270
#    ✅ 첨부파일 1개 발견
#       ✅ [안내]기술거래보호사업, 기술평가사업 활성화를 위한 워크숍 개최 검토_기술보증기금.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [160] 게시판ID: 3793214
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3793214
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3793214
#    ✅ 첨부파일 2개 발견
#       ✅ 2024년 네이버 파트너 임직원 건강검진 프로그램_배포용_v1.0.xlsx
#       ✅ 별첨. KMI_온라인 예약 이용가이드(네이버파트너)_배포용 (1).pdf
#    📊 복사 완료: 2/2개
#
# 📄 [162] 게시판ID: 3786916
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3786916
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3786916
#    ✅ 첨부파일 1개 발견
#       ✅ 생성형 AI기술 개발.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [165] 게시판ID: 3785770
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3785770
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3785770
#    ✅ 첨부파일 1개 발견
#       ✅ 베트남_서비스단가표_20240301.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [172] 게시판ID: 3753183
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3753183
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3753183
#    ✅ 첨부파일 1개 발견
#       ✅ 2024년 해외민간네트워크 신규 선정 결과 통보.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [174] 게시판ID: 3752511
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3752511
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3752511
#    ✅ 첨부파일 2개 발견
#       ✅ 개정세법요약_2023년 연말정산.hwp
#       ✅ 2023 연말정산 신고안내 책자.pdf
#    📊 복사 완료: 2/2개
#
# 📄 [232] 게시판ID: 3622928
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3622928
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3622928
#    ✅ 첨부파일 2개 발견
#       ✅ 퇴직연금 디폴트옵션(사전지정운용제도) FAQ (추가).pdf
#       ✅ 퇴직연금 디폴트옵션(사전지정운용제도) FAQ (배포용).pdf
#    📊 복사 완료: 2/2개
#
# 📄 [244] 게시판ID: 3587824
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3587824
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3587824
#    ✅ 첨부파일 1개 발견
#       ✅ 애니파이브_취업규칙(2023년 04월 30일자 개정안).pdf
#    📊 복사 완료: 1/1개
#
# 📄 [254] 게시판ID: 3559763
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3559763
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3559763
#    ✅ 첨부파일 1개 발견
#       ✅ 2023년 네이버 파트너 임직원 건강검진 프로그램_배포용_v1.0.xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [270] 게시판ID: 3514612
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3514612
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3514612
#    ✅ 첨부파일 2개 발견
#       ✅ 2022년 귀속연말정산 공지.docx
#       ✅ 2022년 귀속 근로자용 연말정산 안내.pdf
#    📊 복사 완료: 2/2개
#
# 📄 [289] 게시판ID: 3483464
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3483464
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3483464
#    ✅ 첨부파일 1개 발견
#       ✅ 애니파이브_라디오 광고.wav
#    📊 복사 완료: 1/1개
#
# 📄 [313] 게시판ID: 3422197
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3422197
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3422197
#    ✅ 첨부파일 1개 발견
#       ✅ 2022년 네이버 파트너 건강검진 프로그램_v1.0.xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [352] 게시판ID: 3346326
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3346326
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3346326
#    ✅ 첨부파일 1개 발견
#       ✅ 애니파이브_본사 및 연구소 전화번호_자리별(20220310).pptx
#    📊 복사 완료: 1/1개
#
# 📄 [356] 게시판ID: 3336453
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3336453
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3336453
#    ✅ 첨부파일 1개 발견
#       ✅ (양식)연구개발계획서_범부처연계형 기술사업화 이어달리기.zip
#    📊 복사 완료: 1/1개
#
# 📄 [357] 게시판ID: 3336449
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3336449
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3336449
#    ✅ 첨부파일 1개 발견
#       ✅ 다년도 R&D 과제(프로젝트 R&D), 이전기술사업화 R&D 과제 수행기업 수요조사].zip
#    📊 복사 완료: 1/1개
#
# 📄 [371] 게시판ID: 3315909
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3315909
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3315909
#    ✅ 첨부파일 2개 발견
#       ✅ 2021년 귀속 근로자용 연말정산 안내.pdf
#       ✅ 2021년 귀속 연말정산 개정세법 내용.hwp
#    📊 복사 완료: 2/2개
#
# 📄 [411] 게시판ID: 3222280
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3222280
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3222280
#    ✅ 첨부파일 1개 발견
#       ✅ D430 프린터 기본 설정 방법.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [430] 게시판ID: 3161574
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3161574
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3161574
#    ✅ 첨부파일 1개 발견
#       ✅ 2021년 네이버 파트너 건강검진 프로그램.xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [443] 게시판ID: 3109357
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3109357
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3109357
#    ✅ 첨부파일 4개 발견
#       ✅ 근로소득자 소득·세액공제 신고서.hwp
#       ✅ 2020년 귀속 연말정산 개정세법.pdf
#       ✅ 2020년 귀속 연말정산간소화 서비스 이용 방법.pdf
#       ✅ 연말정산 간소화 자료 제공 동의 신청 방법.pdf
#    📊 복사 완료: 4/4개
#
# 📄 [451] 게시판ID: 3103192
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3103192
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3103192
#    ✅ 첨부파일 2개 발견
#       ✅ ANYFIVE FONT 설치 파일.exe
#       ✅ ANYFIVE visual identity standards_20210101.pptx
#    📊 복사 완료: 2/2개
#
# 📄 [456] 게시판ID: 3083750
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\3083750
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3083750
#    ✅ 첨부파일 1개 발견
#       ✅ 화상회의(Zoom) 매뉴얼_20201130.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [468] 게시판ID: 3056883
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\3056883
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd3056883
#    ✅ 첨부파일 1개 발견
#       ✅ Setup.exe
#    📊 복사 완료: 1/1개
#
# 📄 [494] 게시판ID: 2995740
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2995740
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2995740
#    ✅ 첨부파일 1개 발견
#       ✅ 2020년_하계휴가일정계획.xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [507] 게시판ID: 2964156
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2964156
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2964156
#    ✅ 첨부파일 2개 발견
#       ✅ 애니파이브_전화번호(20200528).xls
#       ✅ 애니파이브_전화번호_자리별(20200528).pptx
#    📊 복사 완료: 2/2개
#
# 📄 [513] 게시판ID: 2956376
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2956376
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2956376
#    ✅ 첨부파일 2개 발견
#       ✅ (기술지원 및 디자인) 작업 요청서_과제명_YYMMDD.pptx
#       ✅ VRB_한국벤처투자_ 모태펀드출자펀드찾기_AI기술_20200429.pptx
#    📊 복사 완료: 2/2개
#
# 📄 [530] 게시판ID: 2872831
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2872831
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2872831
#    ✅ 첨부파일 4개 발견
#       ✅ 근로소득자소득ㆍ세액공제신고서.hwp
#       ✅ 2019년 귀속 연말정산 참고자료(변경내용 및 조회방법).hwp
#       ✅ 2019년 귀속 근로소득 연말정산 주요내용(국세청).pdf
#       ✅ 2019년 연말정산 안내(직원용)_애니파이브.pdf
#    📊 복사 완료: 4/4개
#
# 📄 [544] 게시판ID: 2835792
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2835792
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2835792
#    ✅ 첨부파일 1개 발견
#       ✅ 특허제도_기초지식.hwp
#    📊 복사 완료: 1/1개
#
# 📄 [547] 게시판ID: 2828148
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2828148
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2828148
#    ✅ 첨부파일 2개 발견
#       ✅ 애니파이브_전화번호_자리별(20191101).pptx
#       ✅ 애니파이브_전화번호(20191101).xls
#    📊 복사 완료: 2/2개
#
# 📄 [561] 게시판ID: 2786033
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2786033
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2786033
#    ✅ 첨부파일 1개 발견
#       ✅ pdf_PATINEX2019_ANYFIVE_SOLUTION_UPDATE (20190905)111.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [564] 게시판ID: 2783925
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2783925
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2783925
#    ✅ 첨부파일 1개 발견
#       ✅ [PATINEX 2019]_Program Schedule.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [566] 게시판ID: 2783125
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2783125
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2783125
#    ✅ 첨부파일 2개 발견
#       ✅ 애니파이브_전화번호_자리별(20190830).pptx
#       ✅ 애니파이브_전화번호(20190830).xls
#    📊 복사 완료: 2/2개
#
# 📄 [579] 게시판ID: 2755503
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2755503
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2755503
#    ✅ 첨부파일 3개 발견
#       ✅ 20190717_142339.jpg
#       ✅ 20190717_143859.jpg
#       ✅ 20190717_142452.jpg
#    📊 복사 완료: 3/3개
#
# 📄 [582] 게시판ID: 2745747
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2745747
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2745747
#    ✅ 첨부파일 1개 발견
#       ✅ 2019년_하계휴가일정계획.xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [585] 게시판ID: 2731559
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2731559
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2731559
#    ✅ 첨부파일 2개 발견
#       ✅ 애니파이브_전화번호(20190601).xls
#       ✅ 애니파이브_전화번호_자리별(20190601).pptx
#    📊 복사 완료: 2/2개
#
# 📄 [590] 게시판ID: 2708083
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2708083
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2708083
#    ✅ 첨부파일 1개 발견
#       ✅ Setup.exe
#    📊 복사 완료: 1/1개
#
# 📄 [591] 게시판ID: 2700240
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2700240
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2700240
#    ✅ 첨부파일 1개 발견
#       ✅ 네이버 파트너 건강검진 지원 프로그램_검진기관별 검진 항목.xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [592] 게시판ID: 2697678
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2697678
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2697678
#    ✅ 첨부파일 2개 발견
#       ✅ ANYFIVE FONT 설치 파일.exe
#       ✅ ANYFIVE visual identity standards_20190422.pptx
#    📊 복사 완료: 2/2개
#
# 📄 [614] 게시판ID: 2628083
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2628083
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2628083
#    ✅ 첨부파일 3개 발견
#       ✅ 2018년귀속편리한연말정산사용자매뉴얼(근로자용).pdf
#       ✅ 편리한연말정산이용을위한기초자료등록안내.pdf
#       ✅ 2018 연말정산 변경사항 참고자료.hwp
#    📊 복사 완료: 3/3개
#
# 📄 [627] 게시판ID: 2596950
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2596950
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2596950
#    ✅ 첨부파일 1개 발견
#       ✅ KakaoTalk_20181204_204908873.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [641] 게시판ID: 2558644
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2558644
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2558644
#    ✅ 첨부파일 2개 발견
#       ✅ 네이버 건강검진 지원 프로그램.pdf
#       ✅ 2018 네이버 파트너 대상 건강검진 지원 상세내역_20180521.xlsx
#    📊 복사 완료: 2/2개
#
# 📄 [651] 게시판ID: 2521924
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2521924
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2521924
#    ✅ 첨부파일 1개 발견
#       ✅ 기술자신고 절차 및 제출서류 안내.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [655] 게시판ID: 2502516
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2502516
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2502516
#    ✅ 첨부파일 2개 발견
#       ✅ 비상약품.jpg
#       ✅ 비상약품목록.jpg
#    📊 복사 완료: 2/2개
#
# 📄 [658] 게시판ID: 2490474
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2490474
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2490474
#    ✅ 첨부파일 1개 발견
#       ✅ 2018년_하계휴가일정계획.xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [668] 게시판ID: 2466016
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2466016
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2466016
#    ✅ 첨부파일 2개 발견
#       ✅ 애니파이브_전화번호_자리별(20180827).pptx
#       ✅ 애니파이브_전화번호(20180827).xls
#    📊 복사 완료: 2/2개
#
# 📄 [701] 게시판ID: 2386513
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2386513
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2386513
#    ✅ 첨부파일 2개 발견
#       ✅ 2017년 연말정산 공제요건과 제출서류.pdf
#       ✅ 2017년귀속편리한연말정산사용자매뉴얼(근로자용)_20171220.pdf
#    📊 복사 완료: 2/2개
#
# 📄 [779] 게시판ID: 2204254
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2204254
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2204254
#    ✅ 첨부파일 3개 발견
#       ✅ 20170401_132136.jpg
#       ✅ 20170401_133104.jpg
#       ✅ 20170401_133327.jpg
#    📊 복사 완료: 3/3개
#
# 📄 [801] 게시판ID: 2157139
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2157139
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2157139
#    ✅ 첨부파일 4개 발견
#       ✅ 연말정산관련근로자확인사항.xlsx
#       ✅ (2016귀속)연말정산요약.pdf
#       ✅ 2016년연말정산안내문.xlsx
#       ✅ 2016년+연말정산+소득세액공제신고서.xlsx
#    📊 복사 완료: 4/4개
#
# 📄 [815] 게시판ID: 2034324
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2034324
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd2034324
#    ✅ 첨부파일 3개 발견
#       ✅ 20161103_180302.jpg
#       ✅ 20161103_180220.jpg
#       ✅ 20161103_123913.jpg
#    📊 복사 완료: 3/3개
#
# 📄 [834] 게시판ID: 1924089
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\1924089
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd1924089
#    ✅ 첨부파일 1개 발견
#       ✅ 2016년_상반기_전사백업리스트(20160721).xls
#    📊 복사 완료: 1/1개
#
# 📄 [862] 게시판ID: 865629
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\865629
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865629
#    ✅ 첨부파일 1개 발견
#       ✅ 차세대그룹웨어_주요기능소개_이관고객참조.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [884] 게시판ID: 865581
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\865581
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865581
#    ✅ 첨부파일 4개 발견
#       ✅ 2015년소득세액공제신고서.xls
#       ✅ 2015년 소득 세액공제신고서.hwp
#       ✅ 2015년 연말정산 안내문.xlsx
#       ✅ 2015년 연말정산 내용요약표.pdf
#    📊 복사 완료: 4/4개
#
# 📄 [892] 게시판ID: 865569
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\865569
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865569
#    ✅ 첨부파일 1개 발견
#       ✅ 애니파이브_전화번호_자리별(20160104).pdf
#    📊 복사 완료: 1/1개
#
# 📄 [917] 게시판ID: 865494
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865494
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865494
#    ✅ 첨부파일 1개 발견
#       ✅ 대전중부 사업조직운영계획.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [921] 게시판ID: 865482
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865482
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865482
#    ✅ 첨부파일 1개 발견
#       ✅ 애니파이브_전화번호_자리별(20150812).pdf
#    📊 복사 완료: 1/1개
#
# 📄 [926] 게시판ID: 865477
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865477
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865477
#    ✅ 첨부파일 4개 발견
#       ✅ 3.부서별 R&R.jpg
#       ✅ 4.부서별 상세인원.jpg
#       ✅ 1.조직변경(조직도).jpg
#       ✅ 2.조직개편내역.jpg
#    📊 복사 완료: 4/4개
#
# 📄 [928] 게시판ID: 865468
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865468
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865468
#    ✅ 첨부파일 1개 발견
#       ✅ 인력운영지침.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [934] 게시판ID: 865460
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865460
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865460
#    ✅ 첨부파일 1개 발견
#       ✅ 2015년_하계휴가일정계획.xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [940] 게시판ID: 865450
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865450
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865450
#    ✅ 첨부파일 1개 발견
#       ✅ Asia Sales meeting June 2015.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [941] 게시판ID: 865449
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865449
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865449
#    ✅ 첨부파일 5개 발견
#       ✅ 위임전결규정_총무.jpg
#       ✅ 위임전결규정_구매.jpg
#       ✅ 위임전결규정_일반경비.jpg
#       ✅ 위임전결규정_사업수행.jpg
#       ✅ 위임전결규정_인사.jpg
#    📊 복사 완료: 5/5개
#
# 📄 [942] 게시판ID: 865447
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865447
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865447
#    ✅ 첨부파일 4개 발견
#       ✅ 조직도1.jpg
#       ✅ 조직도2.jpg
#       ✅ 조직도4.jpg
#       ✅ 조직도3.jpg
#    📊 복사 완료: 4/4개
#
# 📄 [960] 게시판ID: 865400
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865400
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865400
#    ✅ 첨부파일 2개 발견
#       ✅ 조직도1.PNG
#       ✅ 조직도2.PNG
#    📊 복사 완료: 2/2개
#
# 📄 [976] 게시판ID: 865350
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865350
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865350
#    ✅ 첨부파일 5개 발견
#       ✅ 20150207_121253.jpeg
#       ✅ 20150207_121304.jpeg
#       ✅ 20150207_123133.jpeg
#       ✅ 20150207_133545.jpeg
#       ✅ 20150207_133559.jpeg
#    📊 복사 완료: 5/5개
#
# 📄 [977] 게시판ID: 865349
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865349
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865349
#    ✅ 첨부파일 3개 발견
#       ✅ 20150205_193000.jpeg
#       ✅ 20150205_193012.jpeg
#       ✅ 20150205_193049.jpeg
#    📊 복사 완료: 3/3개
#
# 📄 [983] 게시판ID: 865328
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865328
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865328
#    ✅ 첨부파일 4개 발견
#       ✅ 근로소득자소득.세액공제신고서.xls
#       ✅ 근로소득자소득.세액공제신고서.hwp
#       ✅ 2014년_귀속_연말정산_안내문.hwp
#       ✅ 2014년_귀속 연말정산_메뉴얼(상세).pdf
#    📊 복사 완료: 4/4개
#
# 📄 [1005] 게시판ID: 865272
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865272
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865272
#    ✅ 첨부파일 1개 발견
#       ✅ LG와함께하는 협력사 임직원 전용 복지몰 회원가입 방법 가이드.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [1009] 게시판ID: 865262
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865262
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865262
#    ✅ 첨부파일 1개 발견
#       ✅ aaaaaaa.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1042] 게시판ID: 865174
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865174
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865174
#    ✅ 첨부파일 1개 발견
#       ✅ 2014년_상반기_전사백업리스트(20140715).xls
#    📊 복사 완료: 1/1개
#
# 📄 [1062] 게시판ID: 865134
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865134
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865134
#    ✅ 첨부파일 1개 발견
#       ✅ 애니파이브_정보보안 인식제고(20140501).pdf
#    📊 복사 완료: 1/1개
#
# 📄 [1093] 게시판ID: 865051
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865051
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865051
#    ✅ 첨부파일 4개 발견
#       ✅ 2013 연말정산 안내문.doc
#       ✅ 2013년_귀속_연말정산_개정세법.pdf
#       ✅ 2013 소득공제신고서 (2013.09.27 개정).hwp
#       ✅ 2013 소득공제신고서 (2013.09.27 개정).xls
#    📊 복사 완료: 4/4개
#
# 📄 [1094] 게시판ID: 865050
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865050
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865050
#    ✅ 첨부파일 1개 발견
#       ✅ 2013년_하반기_전사백업리스트(20140116).xls
#    📊 복사 완료: 1/1개
#
# 📄 [1103] 게시판ID: 865024
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865024
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd865024
#    ✅ 첨부파일 2개 발견
#       ✅ 애니파이브_전화번호_자리별(20140106).ppt
#       ✅ 애니파이브_전화번호(20140107).xls
#    📊 복사 완료: 2/2개
#
# 📄 [1123] 게시판ID: 864988
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864988
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd864988
#    ✅ 첨부파일 1개 발견
#       ✅ 성희롱예방교육_영상.wmv
#    📊 복사 완료: 1/1개
#
# 📄 [1132] 게시판ID: 864967
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864967
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd864967
#    ✅ 첨부파일 2개 발견
#       ✅ 애니파이브_전화번호(20131101).pdf
#       ✅ 애니파이브_전화번호_자리별(20131101).ppt
#    📊 복사 완료: 2/2개
#
# 📄 [1164] 게시판ID: 864847
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864847
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd864847
#    ✅ 첨부파일 2개 발견
#       ✅ 애니파이브_전화번호(20130724).xls
#       ✅ 애니파이브_전화번호_자리별(20130724).ppt
#    📊 복사 완료: 2/2개
#
# 📄 [1184] 게시판ID: 864797
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864797
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd864797
#    ✅ 첨부파일 1개 발견
#       ✅ 2013년_상반기_전사백업리스트(20130613).xls
#    📊 복사 완료: 1/1개
#
# 📄 [1196] 게시판ID: 864732
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864732
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd864732
#    ✅ 첨부파일 2개 발견
#       ✅ 애니파이브_전화번호(20130506).xls
#       ✅ 애니파이브_전화번호_자리별(20130506).ppt
#    📊 복사 완료: 2/2개
#
# 📄 [1211] 게시판ID: 864634
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864634
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd864634
#    ✅ 첨부파일 1개 발견
#       ✅ 첨부1.2013년_협력회사_전체 일정표_V1.0.xls
#    📊 복사 완료: 1/1개
#
# 📄 [1224] 게시판ID: 864548
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864548
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd864548
#    ✅ 첨부파일 5개 발견
#       ✅ 결재라인_인사교육.jpg
#       ✅ 결재라인_총무.jpg
#       ✅ 결재라인_구매.jpg
#       ✅ 결제라인_일반경비.jpg
#       ✅ 결재라인_사업수행.jpg
#    📊 복사 완료: 5/5개
#
# 📄 [1228] 게시판ID: 864530
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864530
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd864530
#    ✅ 첨부파일 3개 발견
#       ✅ 공정위 표준계약서(4종).zip
#       ✅ 양식_계약변경 합의서.docx
#       ✅ 재하도급 사전승인 양식.zip
#    📊 복사 완료: 3/3개
#
# 📄 [1232] 게시판ID: 864516
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864516
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd864516
#    ✅ 첨부파일 3개 발견
#       ✅ 2012년_연말정산안내문_회계법인자료.rtf
#       ✅ 2012년_근로소득공제신고서.hwp
#       ✅ 2012년_근로소득공제신고서.xls
#    📊 복사 완료: 3/3개
#
# 📄 [1256] 게시판ID: 864438
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864438
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd864438
#    ✅ 첨부파일 1개 발견
#       ✅ SINDOH D400_드라이버 - 복사본.zip
#    📊 복사 완료: 1/1개
#
# 📄 [1279] 게시판ID: 864342
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864342
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd864342
#    ✅ 첨부파일 1개 발견
#       ✅ 법인카드_사용내역보고(20120801).xls
#    📊 복사 완료: 1/1개
#
# 📄 [1304] 게시판ID: 864246
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864246
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd864246
#    ✅ 첨부파일 2개 발견
#       ✅ 법인카드_증빙첨부(20120401).xls
#       ✅ 법인카드_사용내역보고(20120401).xls
#    📊 복사 완료: 2/2개
#
# 📄 [1326] 게시판ID: 864104
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864104
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd864104
#    ✅ 첨부파일 3개 발견
#       ✅ 2011년_연말정산안내문_회계법인자료.pdf
#       ✅ 양식_근로자소득공제신고서.hwp
#       ✅ 양식_근로자소득공제신고서.xls
#    📊 복사 완료: 3/3개
#
# 📄 [1346] 게시판ID: 864040
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864040
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd864040
#    ✅ 첨부파일 1개 발견
#       ✅ PDF김기종송부용_FIP논문_최종보고_지재서비스(요약).pdf
#    📊 복사 완료: 1/1개
#
# 📄 [1357] 게시판ID: 863994
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\863994
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd863994
#    ✅ 첨부파일 3개 발견
#       ✅ 법인카드_증빙첨부(20110801).xls
#       ✅ 예시_법인카드_증빙첨부.JPG
#       ✅ 법인카드_사용내역보고(20120101).xls
#    📊 복사 완료: 3/3개
#
# 📄 [1368] 게시판ID: 863966
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\863966
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd863966
#    ✅ 첨부파일 1개 발견
#       ✅ 명함샘플제작(20110719).gif
#    📊 복사 완료: 1/1개
#
# 📄 [1376] 게시판ID: 863943
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\863943
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd863943
#    ✅ 첨부파일 1개 발견
#       ✅ 사내동호회운영규정_공지.doc
#    📊 복사 완료: 1/1개
#
# 📄 [1394] 게시판ID: 863869
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\863869
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd863869
#    ✅ 첨부파일 3개 발견
#       ✅ 법인카드_사용내역보고(20110301).xls
#       ✅ 법인카드_증빙첨부(20110301).xls
#       ✅ 예시_법인카드_증빙첨부.JPG
#    📊 복사 완료: 3/3개
#
# 📄 [1422] 게시판ID: 863801
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\863801
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd863801
#    ✅ 첨부파일 1개 발견
#       ✅ 건강보험료인상안.PDF
#    📊 복사 완료: 1/1개
#
# 📄 [1423] 게시판ID: 863800
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\863800
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd863800
#    ✅ 첨부파일 1개 발견
#       ✅ 소득공제신고서2010[1].hwp
#    📊 복사 완료: 1/1개
#
# 📄 [1519] 게시판ID: 863309
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\863309
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd863309
#    ✅ 첨부파일 3개 발견
#       ✅ 2)3개과정(18개코스) 교육내용.hwp
#       ✅ 3)점프(Jump)교육참여신청서 및 직무역량진단도구.hwp
#       ✅ 1)교육과정안내 및 일정.hwp
#    📊 복사 완료: 3/3개
#
# 📄 [1544] 게시판ID: 863177
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\863177
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd863177
#    ✅ 첨부파일 1개 발견
#       ✅ etc_20100204.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1547] 게시판ID: 863143
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\863143
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd863143
#    ✅ 첨부파일 1개 발견
#       ✅ sample123.pot
#    📊 복사 완료: 1/1개
#
# 📄 [1554] 게시판ID: 863038
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\863038
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd863038
#    ✅ 첨부파일 2개 발견
#       ✅ 근로소득자공제신고서.hwp
#       ✅ 근무지(변동)신고서.hwp
#    📊 복사 완료: 2/2개
#
# 📄 [1581] 게시판ID: 862960
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862960
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862960
#    ✅ 첨부파일 1개 발견
#       ✅ KAIPS_IP포럼발표_20091210.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [1582] 게시판ID: 862959
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862959
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862959
#    ✅ 첨부파일 1개 발견
#       ✅ (공문)제3회_포럼_및_송년_행사_개최_KAIPS.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1585] 게시판ID: 862956
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862956
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862956
#    ✅ 첨부파일 1개 발견
#       ✅ 1차_임원워크샵_공지(20091127).jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1587] 게시판ID: 862954
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862954
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862954
#    ✅ 첨부파일 1개 발견
#       ✅ 신인임원(김기두이사)입사안내.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1589] 게시판ID: 862952
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862952
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862952
#    ✅ 첨부파일 1개 발견
#       ✅ 전기연구원_R&D구축사업.gif
#    📊 복사 완료: 1/1개
#
# 📄 [1590] 게시판ID: 862951
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862951
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862951
#    ✅ 첨부파일 1개 발견
#       ✅ 전사워크샵공지수정.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1591] 게시판ID: 862950
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862950
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862950
#    ✅ 첨부파일 1개 발견
#       ✅ KT지재권_구축사업.gif
#    📊 복사 완료: 1/1개
#
# 📄 [1592] 게시판ID: 862949
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862949
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862949
#    ✅ 첨부파일 1개 발견
#       ✅ Surety,Absoluteproof_서비스체결.gif
#    📊 복사 완료: 1/1개
#
# 📄 [1593] 게시판ID: 862948
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862948
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862948
#    ✅ 첨부파일 1개 발견
#       ✅ patinex2009_전시회.wmv
#    📊 복사 완료: 1/1개
#
# 📄 [1595] 게시판ID: 862946
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862946
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862946
#    ✅ 첨부파일 1개 발견
#       ✅ patinex2009_특허청장방문.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1596] 게시판ID: 862945
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862945
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862945
#    ✅ 첨부파일 1개 발견
#       ✅ patinex2009_로고.gif
#    📊 복사 완료: 1/1개
#
# 📄 [1598] 게시판ID: 862943
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862943
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862943
#    ✅ 첨부파일 1개 발견
#       ✅ 2009_전자신문 정보망구축.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1604] 게시판ID: 862937
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862937
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862937
#    ✅ 첨부파일 1개 발견
#       ✅ 2009지식재산강국_전자신문.gif
#    📊 복사 완료: 1/1개
#
# 📄 [1605] 게시판ID: 862936
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862936
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862936
#    ✅ 첨부파일 1개 발견
#       ✅ 2008펜택스_개최안내.gif
#    📊 복사 완료: 1/1개
#
# 📄 [1607] 게시판ID: 862934
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862934
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862934
#    ✅ 첨부파일 1개 발견
#       ✅ 2009입사_고화석이사.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1608] 게시판ID: 862933
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862933
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862933
#    ✅ 첨부파일 1개 발견
#       ✅ 2009식약청_구축사업수주안내.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1609] 게시판ID: 862932
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862932
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862932
#    ✅ 첨부파일 1개 발견
#       ✅ 예방조치안내.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1611] 게시판ID: 862930
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862930
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862930
#    ✅ 첨부파일 1개 발견
#       ✅ R&D관련 용어정리
#    📊 복사 완료: 1/1개
#
# 📄 [1612] 게시판ID: 862929
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862929
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862929
#    ✅ 첨부파일 1개 발견
#       ✅ ceo매거진잡지.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1619] 게시판ID: 862922
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862922
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862922
#    ✅ 첨부파일 1개 발견
#       ✅ 전자신문_인터뷰.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1620] 게시판ID: 862921
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862921
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862921
#    ✅ 첨부파일 1개 발견
#       ✅ 전면광고.gif
#    📊 복사 완료: 1/1개
#
# 📄 [1623] 게시판ID: 862918
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862918
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862918
#    ✅ 첨부파일 1개 발견
#       ✅ 김성연k_김보민돌초대장.gif
#    📊 복사 완료: 1/1개
#
# 📄 [1635] 게시판ID: 862906
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862906
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862906
#    ✅ 첨부파일 1개 발견
#       ✅ SW기술자신고가이드(0).zip
#    📊 복사 완료: 1/1개
#
# 📄 [1640] 게시판ID: 862901
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862901
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862901
#    ✅ 첨부파일 1개 발견
#       ✅ 2009상반기결산_워크샵안내.gif
#    📊 복사 완료: 1/1개
#
# 📄 [1641] 게시판ID: 862882
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862882
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862882
#    ✅ 첨부파일 1개 발견
#       ✅ 서비스R&D의개념.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1643] 게시판ID: 862880
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862880
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862880
#    ✅ 첨부파일 1개 발견
#       ✅ 공통출원서식 도입.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1644] 게시판ID: 862879
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862879
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862879
#    ✅ 첨부파일 2개 발견
#       ✅ LGCNS전문특화군운영방안.bmp
#       ✅ 2009년전문업체(선정결과요약1P).jpg
#    📊 복사 완료: 2/2개
#
# 📄 [1645] 게시판ID: 862878
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862878
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862878
#    ✅ 첨부파일 1개 발견
#       ✅ 청첩장(박정균).jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1646] 게시판ID: 862877
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862877
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862877
#    ✅ 첨부파일 2개 발견
#       ✅ 윤상호C자녀돌잔치.bmp
#       ✅ 돌잔치_초대장.JPG
#    📊 복사 완료: 2/2개
#
# 📄 [1652] 게시판ID: 862871
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862871
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862871
#    ✅ 첨부파일 1개 발견
#       ✅ 대한민국신성장동력우수기업선정.gif
#    📊 복사 완료: 1/1개
#
# 📄 [1658] 게시판ID: 862865
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862865
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862865
#    ✅ 첨부파일 1개 발견
#       ✅ 2009년2월_운영결과보고서-사이트명_20090205.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [1661] 게시판ID: 862862
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862862
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862862
#    ✅ 첨부파일 3개 발견
#       ✅ 근무지(변동)신고서.HWP
#       ✅ 2008근로소득공제.jpg
#       ✅ 근로소득자소득공제신고서.hwp
#    📊 복사 완료: 3/3개
#
# 📄 [1664] 게시판ID: 862859
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862859
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862859
#    ✅ 첨부파일 1개 발견
#       ✅ 김성수이사.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1666] 게시판ID: 862857
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862857
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862857
#    ✅ 첨부파일 1개 발견
#       ✅ 애니파이브시스템_시무식_20090110(게시용).pdf
#    📊 복사 완료: 1/1개
#
# 📄 [1667] 게시판ID: 862856
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862856
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862856
#    ✅ 첨부파일 1개 발견
#       ✅ 2009주요행사일정안내.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1668] 게시판ID: 862855
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862855
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862855
#    ✅ 첨부파일 1개 발견
#       ✅ 2009주요회의체안내.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1675] 게시판ID: 862848
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862848
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862848
#    ✅ 첨부파일 1개 발견
#       ✅ P2MS개선 프로젝트 종료평가 결과공유.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1676] 게시판ID: 862847
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862847
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862847
#    ✅ 첨부파일 1개 발견
#       ✅ 2008 TIPIS개선내역시스템오픈.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1679] 게시판ID: 862844
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862844
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862844
#    ✅ 첨부파일 1개 발견
#       ✅ 애니파이브안식년휴가1호.gif
#    📊 복사 완료: 1/1개
#
# 📄 [1683] 게시판ID: 862840
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862840
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862840
#    ✅ 첨부파일 1개 발견
#       ✅ 추계워크샵배차안내.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1684] 게시판ID: 862839
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862839
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862839
#    ✅ 첨부파일 1개 발견
#       ✅ 2006안면도추계행사.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1685] 게시판ID: 862838
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862838
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862838
#    ✅ 첨부파일 1개 발견
#       ✅ 2008추계워크샵.gif
#    📊 복사 완료: 1/1개
#
# 📄 [1695] 게시판ID: 862828
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862828
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862828
#    ✅ 첨부파일 1개 발견
#       ✅ 프로젝트코드등록절차.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1696] 게시판ID: 862827
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862827
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862827
#    ✅ 첨부파일 1개 발견
#       ✅ 2008사무실확장이전안내.gif
#    📊 복사 완료: 1/1개
#
# 📄 [1701] 게시판ID: 862822
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862822
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862822
#    ✅ 첨부파일 2개 발견
#       ✅ 총회_행사진행.hwp
#       ✅ 서비스협회_초청(공문).hwp
#    📊 복사 완료: 2/2개
#
# 📄 [1709] 게시판ID: 862814
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862814
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862814
#    ✅ 첨부파일 1개 발견
#       ✅ 2008조직도.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1710] 게시판ID: 862813
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862813
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862813
#    ✅ 첨부파일 1개 발견
#       ✅ 애니파이브시스템_시무식_20080104.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [1711] 게시판ID: 862812
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862812
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862812
#    ✅ 첨부파일 2개 발견
#       ✅ 2007연말정산필요서류.jpg
#       ✅ 소득공제_제출서류(상세).hwp
#    📊 복사 완료: 2/2개
#
# 📄 [1714] 게시판ID: 862809
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862809
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862809
#    ✅ 첨부파일 1개 발견
#       ✅ 2008경영계획(20071215).pdf
#    📊 복사 완료: 1/1개
#
# 📄 [1715] 게시판ID: 862808
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862808
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862808
#    ✅ 첨부파일 1개 발견
#       ✅ Innovation_2007_ANYFIVE_PT_Material_(Thu[1]._6th_Dec.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [1716] 게시판ID: 862807
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862807
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862807
#    ✅ 첨부파일 1개 발견
#       ✅ 신sw대상추천작071120.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1721] 게시판ID: 862802
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862802
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862802
#    ✅ 첨부파일 2개 발견
#       ✅ SmileANYFIVE_WIDE2.jpg
#       ✅ SmileANYFIVE0907.jpg
#    📊 복사 완료: 2/2개
#
# 📄 [1725] 게시판ID: 862798
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862798
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862798
#    ✅ 첨부파일 1개 발견
#       ✅ 신규계약및수행과정.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1728] 게시판ID: 862795
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862795
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862795
#    ✅ 첨부파일 1개 발견
#       ✅ 20070630 정보공유워크샵.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1735] 게시판ID: 862788
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862788
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862788
#    ✅ 첨부파일 1개 발견
#       ✅ 2006실적및2007경영계획(20070106).ppt
#    📊 복사 완료: 1/1개
#
# 📄 [1736] 게시판ID: 862787
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862787
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862787
#    ✅ 첨부파일 1개 발견
#       ✅ 2006전사정보공유회의.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1738] 게시판ID: 862785
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862785
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862785
#    ✅ 첨부파일 1개 발견
#       ✅ 2006매일경제통합솔루션개발.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1741] 게시판ID: 862782
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862782
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862782
#    ✅ 첨부파일 2개 발견
#       ✅ SmileANYFIVE.jpg
#       ✅ SmileANYFIVE_WIDE.jpg
#    📊 복사 완료: 2/2개
#
# 📄 [1742] 게시판ID: 862781
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862781
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862781
#    ✅ 첨부파일 1개 발견
#       ✅ 2006안면도추계행사.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [1743] 게시판ID: 862780
#    원본: C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd\862780
#    복사: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments\brd862780
#    ✅ 첨부파일 1개 발견
#       ✅ 신SW 상품대산추천작.gif
#    📊 복사 완료: 1/1개
#
# ============================================================
# ✅ 처리 완료!
#    - 게시판 타입: biz
#    - 첨부파일 있는 posts: 166개
#    - 총 첨부파일 개수: 258개
#    - 복사된 파일 위치: C:\Users\LEEJUHWAN\Downloads\board_biz_attachments
#    - DB 테이블: board_posts (attaches_json 컬럼 업데이트)
# ============================================================
#
# ✅ DB 연결 종료

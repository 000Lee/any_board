# %%
# 이미지 경로 변환 - DB 직접 연동 버전
# type 컬럼으로 게시판 선택

import json
import os
import shutil
import re
from pathlib import Path
import pymysql
from sqlalchemy import create_engine

# ==================== DB 설정 ====================
USER = "root"
PASS = "1234"
HOST = "127.0.0.1"
PORT = 3306
DB = "crawling"

# ==================== 설정 영역 (여기를 수정하세요) ====================

# 게시판 타입 (필터링용)
BOARD_TYPE = "free"  # ✨ 추가: hredu, cp, sales 등

# 이미지 원본 경로들 - 여러 경로 추가 가능
BASE_IMAGE_PATHS = [
    r"C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\namoeditor",
    r"C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\image\daumeditor",
    r"C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\namoeditor",
    r"C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor",
    # 더 추가하고 싶으면 여기에 계속 추가
]

# 이미지 복사본 저장 폴더 (타입별로 자동 생성)
OUTPUT_IMAGE_FOLDER = rf"C:\Users\LEEJUHWAN\Downloads\board_{BOARD_TYPE}_img"  # ✨ 타입 반영

# src에서 제거할 접두사 (이 부분을 제거하고 상대경로로 변경)
REMOVE_PREFIX = r"C:\Users\LEEJUHWAN\Downloads"

# ======================================================================


def find_image_folder(folder_name):
    """여러 경로에서 이미지 폴더 찾기"""
    for base_path in BASE_IMAGE_PATHS:
        image_folder = Path(base_path) / folder_name
        if image_folder.exists():
            return image_folder
    return None


def process_single_post(data, post_index):
    """하나의 post 데이터 처리"""
    
    # sourceId에서 문서ID 추출
    source_id = data.get('sourceId', '')
    if not source_id:
        print(f"⚠️ [{post_index}] sourceId 없음, 건너뜀")
        return data  # 원본 그대로 반환
    
    doc_id = source_id.lstrip('_')
    folder_name = f"brd{doc_id}"
    
    # 여러 경로에서 이미지 폴더 찾기
    image_folder = find_image_folder(folder_name)
    
    if not image_folder:
        print(f"⚠️ [{post_index}] 폴더 없음: {folder_name} (모든 경로 검색 완료)")
        return data  # 원본 그대로 반환
    
    # 복사본 저장할 문서별 폴더 생성
    output_doc_folder = Path(OUTPUT_IMAGE_FOLDER) / folder_name
    output_doc_folder.mkdir(parents=True, exist_ok=True)
    
    print(f"\n📄 [{post_index}] 문서ID: {doc_id}")
    print(f"   원본: {image_folder}")
    print(f"   복사: {output_doc_folder}")
    
    # HTML에서 img 태그 찾기
    html_content = data.get('content', '')
    if not html_content:
        print(f"   ⚠️ content 없음")
        return data
    
    img_pattern = r'<img[^>]+src="([^"]+)"[^>]*>'
    img_matches = list(re.finditer(img_pattern, html_content))
    
    if not img_matches:
        print(f"   ℹ️ 이미지 없음")
        return data
    
    print(f"   ✅ 이미지 {len(img_matches)}개 발견")
    
    # 파일 복사 & src 경로 변경
    new_html = html_content
    copied_count = 0
    
    for idx, match in enumerate(img_matches):
        old_src = match.group(1)
        
        # 원본 파일 (0, 1, 2...)
        old_file = image_folder / str(idx)
        
        # 복사본 파일 (.jpg 확장자 추가)
        new_file = output_doc_folder / f"{idx}.jpg"
        
        # 파일 복사
        if old_file.exists():
            shutil.copy2(old_file, new_file)
            copied_count += 1
            print(f"      ✅ {old_file.name} → {new_file.name}")
            
            # src 경로 변경 (상대경로로)
            new_src = str(new_file).replace('\\', '/')
            if REMOVE_PREFIX:
                prefix_with_slash = REMOVE_PREFIX.replace('\\', '/')
                if new_src.startswith(prefix_with_slash):
                    new_src = new_src[len(prefix_with_slash):].lstrip('/')
            
            new_html = new_html.replace(old_src, new_src, 1)
        else:
            print(f"      ⚠️ 파일 없음: {old_file.name} - src 공란 처리")
            # src를 빈 문자열로 변경
            new_html = new_html.replace(old_src, '', 1)
    
    print(f"   📊 복사 완료: {copied_count}/{len(img_matches)}개")
    
    # 수정된 HTML 적용
    data['content'] = new_html
    return data


def process_db(board_type):
    """DB에서 특정 type의 데이터만 읽고 처리 후 DB에 업데이트"""
    
    # 출력 폴더 생성
    os.makedirs(OUTPUT_IMAGE_FOLDER, exist_ok=True)
    
    # DB 연결
    print(f"📂 DB 연결 중...")
    print(f"📂 게시판 타입: {board_type}")  # ✨ 추가
    print(f"📂 검색할 이미지 경로: {len(BASE_IMAGE_PATHS)}개\n")
    
    connection = pymysql.connect(
        host=HOST,
        user=USER,
        password=PASS,
        database=DB,
        port=PORT,
        charset='utf8mb4'
    )
    
    try:
        with connection.cursor(pymysql.cursors.DictCursor) as cursor:
            # 1. DB에서 특정 type의 데이터만 읽기
            query = "SELECT * FROM board_posts WHERE type = %s"  # ✨ WHERE 조건 추가
            cursor.execute(query, (board_type,))
            posts = cursor.fetchall()
            
            total_count = len(posts)
            print(f"✅ 총 {total_count}개의 posts 발견\n")
            
            # 2. 각 post 처리
            processed_count = 0
            
            for idx, post in enumerate(posts, 1):
                try:
                    # 원본 content 저장 (비교용)
                    original_content = post.get('content', '')
                    
                    # attaches_json을 파싱하여 attaches로 변환
                    if post.get('attaches_json'):
                        post['attaches'] = json.loads(post['attaches_json'])
                    else:
                        post['attaches'] = []
                    
                    # 기존 로직 그대로 사용
                    result = process_single_post(post, idx)
                    
                    # content가 변경된 경우만 DB 업데이트
                    if result['content'] != original_content:
                        update_query = """
                            UPDATE board_posts 
                            SET content = %s 
                            WHERE sourceId = %s AND type = %s
                        """  # ✨ WHERE 조건에 type도 추가
                        cursor.execute(update_query, (result['content'], result['sourceId'], board_type))
                        processed_count += 1
                    
                except Exception as e:
                    print(f"❌ [Post {idx}] 처리 오류: {e}")
                    continue
            
            # 변경사항 커밋
            connection.commit()
            
            print(f"\n{'='*60}")
            print(f"✅ 처리 완료!")
            print(f"   - 게시판 타입: {board_type}")  # ✨ 추가
            print(f"   - 처리된 posts: {processed_count}/{total_count}개")
            print(f"   - 복사된 이미지 위치: {OUTPUT_IMAGE_FOLDER}")
            print(f"   - DB 테이블: board_posts (content 컬럼 업데이트)")
            print(f"{'='*60}")
    
    finally:
        connection.close()
        print("\n✅ DB 연결 종료")


# 실행
if __name__ == "__main__":
    process_db(BOARD_TYPE)  # ✨ board_type 인자 추가
# Out:
# 📂 DB 연결 중...
# 📂 게시판 타입: free
# 📂 검색할 이미지 경로: 4개
#
# ✅ 총 262개의 posts 발견
#
# ⚠️ [1] 폴더 없음: brd3133926 (모든 경로 검색 완료)
#
# 📄 [2] 문서ID: 2996318
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2996318
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2996318
#    ✅ 이미지 3개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#    📊 복사 완료: 3/3개
# ⚠️ [3] 폴더 없음: brd2741605 (모든 경로 검색 완료)
#
# 📄 [4] 문서ID: 2642799
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2642799
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2642799
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [5] 문서ID: 2633712
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2633712
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2633712
#    ✅ 이미지 3개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#    📊 복사 완료: 3/3개
#
# 📄 [6] 문서ID: 2633676
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2633676
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2633676
#    ✅ 이미지 5개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#       ✅ 3 → 3.jpg
#       ✅ 4 → 4.jpg
#    📊 복사 완료: 5/5개
#
# 📄 [7] 문서ID: 2516554
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2516554
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2516554
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [8] 문서ID: 2397706
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2397706
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2397706
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [9] 폴더 없음: brd2397353 (모든 경로 검색 완료)
#
# 📄 [10] 문서ID: 2324738
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2324738
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2324738
#    ✅ 이미지 7개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#       ✅ 3 → 3.jpg
#       ✅ 4 → 4.jpg
#       ✅ 5 → 5.jpg
#       ✅ 6 → 6.jpg
#    📊 복사 완료: 7/7개
#
# 📄 [11] 문서ID: 2305919
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2305919
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2305919
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [12] 폴더 없음: brd2269575 (모든 경로 검색 완료)
#
# 📄 [13] 문서ID: 2245463
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2245463
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2245463
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [14] 문서ID: 2219794
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2219794
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2219794
#    ✅ 이미지 13개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#       ✅ 3 → 3.jpg
#       ✅ 4 → 4.jpg
#       ✅ 5 → 5.jpg
#       ✅ 6 → 6.jpg
#       ✅ 7 → 7.jpg
#       ✅ 8 → 8.jpg
#       ✅ 9 → 9.jpg
#       ✅ 10 → 10.jpg
#       ✅ 11 → 11.jpg
#       ✅ 12 → 12.jpg
#    📊 복사 완료: 13/13개
#
# 📄 [15] 문서ID: 2202660
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2202660
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2202660
#    ✅ 이미지 6개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#       ✅ 3 → 3.jpg
#       ✅ 4 → 4.jpg
#       ⚠️ 파일 없음: 5 - src 공란 처리
#    📊 복사 완료: 5/6개
# ⚠️ [16] 폴더 없음: brd2170422 (모든 경로 검색 완료)
#
# 📄 [17] 문서ID: 2151740
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2151740
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2151740
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [18] 문서ID: 2101510
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2101510
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2101510
#    ✅ 이미지 4개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#       ✅ 2 → 2.jpg
#       ✅ 3 → 3.jpg
#    📊 복사 완료: 4/4개
#
# 📄 [19] 문서ID: 2098978
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2098978
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2098978
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [20] 문서ID: 2042907
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2042907
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2042907
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [21] 문서ID: 2037173
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2037173
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2037173
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [22] 문서ID: 2022320
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2022320
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2022320
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [23] 문서ID: 2016234
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2016234
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2016234
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [24] 문서ID: 2004152
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd2004152
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd2004152
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
#
# 📄 [25] 문서ID: 1990884
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd1990884
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd1990884
#    ✅ 이미지 1개 발견
#       ✅ 0 → 0.jpg
#    📊 복사 완료: 1/1개
# ⚠️ [26] 폴더 없음: brd996669 (모든 경로 검색 완료)
# ⚠️ [27] 폴더 없음: brd990692 (모든 경로 검색 완료)
# ⚠️ [28] 폴더 없음: brd990682 (모든 경로 검색 완료)
#
# 📄 [29] 문서ID: 958384
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\image\daumeditor\brd958384
#    복사: C:\Users\LEEJUHWAN\Downloads\board_free_img\brd958384
#    ✅ 이미지 2개 발견
#       ✅ 0 → 0.jpg
#       ✅ 1 → 1.jpg
#    📊 복사 완료: 2/2개
# ⚠️ [30] 폴더 없음: brd865628 (모든 경로 검색 완료)
# ⚠️ [31] 폴더 없음: brd865619 (모든 경로 검색 완료)
# ⚠️ [32] 폴더 없음: brd865618 (모든 경로 검색 완료)
# ⚠️ [33] 폴더 없음: brd865617 (모든 경로 검색 완료)
# ⚠️ [34] 폴더 없음: brd865612 (모든 경로 검색 완료)
# ⚠️ [35] 폴더 없음: brd865609 (모든 경로 검색 완료)
# ⚠️ [36] 폴더 없음: brd865532 (모든 경로 검색 완료)
# ⚠️ [37] 폴더 없음: brd865529 (모든 경로 검색 완료)
# ⚠️ [38] 폴더 없음: brd865524 (모든 경로 검색 완료)
# ⚠️ [39] 폴더 없음: brd865512 (모든 경로 검색 완료)
# ⚠️ [40] 폴더 없음: brd865484 (모든 경로 검색 완료)
# ⚠️ [41] 폴더 없음: brd865443 (모든 경로 검색 완료)
# ⚠️ [42] 폴더 없음: brd865442 (모든 경로 검색 완료)
# ⚠️ [43] 폴더 없음: brd865441 (모든 경로 검색 완료)
# ⚠️ [44] 폴더 없음: brd865409 (모든 경로 검색 완료)
# ⚠️ [45] 폴더 없음: brd865403 (모든 경로 검색 완료)
# ⚠️ [46] 폴더 없음: brd865389 (모든 경로 검색 완료)
# ⚠️ [47] 폴더 없음: brd865388 (모든 경로 검색 완료)
# ⚠️ [48] 폴더 없음: brd865372 (모든 경로 검색 완료)
# ⚠️ [49] 폴더 없음: brd865321 (모든 경로 검색 완료)
# ⚠️ [50] 폴더 없음: brd865313 (모든 경로 검색 완료)
# ⚠️ [51] 폴더 없음: brd865312 (모든 경로 검색 완료)
# ⚠️ [52] 폴더 없음: brd865303 (모든 경로 검색 완료)
# ⚠️ [53] 폴더 없음: brd865302 (모든 경로 검색 완료)
# ⚠️ [54] 폴더 없음: brd865301 (모든 경로 검색 완료)
# ⚠️ [55] 폴더 없음: brd865289 (모든 경로 검색 완료)
# ⚠️ [56] 폴더 없음: brd865276 (모든 경로 검색 완료)
# ⚠️ [57] 폴더 없음: brd865209 (모든 경로 검색 완료)
# ⚠️ [58] 폴더 없음: brd865195 (모든 경로 검색 완료)
# ⚠️ [59] 폴더 없음: brd865188 (모든 경로 검색 완료)
# ⚠️ [60] 폴더 없음: brd865171 (모든 경로 검색 완료)
# ⚠️ [61] 폴더 없음: brd865165 (모든 경로 검색 완료)
# ⚠️ [62] 폴더 없음: brd865164 (모든 경로 검색 완료)
# ⚠️ [63] 폴더 없음: brd865163 (모든 경로 검색 완료)
# ⚠️ [64] 폴더 없음: brd865162 (모든 경로 검색 완료)
# ⚠️ [65] 폴더 없음: brd865160 (모든 경로 검색 완료)
# ⚠️ [66] 폴더 없음: brd865152 (모든 경로 검색 완료)
# ⚠️ [67] 폴더 없음: brd865145 (모든 경로 검색 완료)
# ⚠️ [68] 폴더 없음: brd865140 (모든 경로 검색 완료)
# ⚠️ [69] 폴더 없음: brd865137 (모든 경로 검색 완료)
# ⚠️ [70] 폴더 없음: brd865126 (모든 경로 검색 완료)
# ⚠️ [71] 폴더 없음: brd865125 (모든 경로 검색 완료)
# ⚠️ [72] 폴더 없음: brd865124 (모든 경로 검색 완료)
# ⚠️ [73] 폴더 없음: brd865123 (모든 경로 검색 완료)
# ⚠️ [74] 폴더 없음: brd865119 (모든 경로 검색 완료)
# ⚠️ [75] 폴더 없음: brd865115 (모든 경로 검색 완료)
# ⚠️ [76] 폴더 없음: brd865114 (모든 경로 검색 완료)
# ⚠️ [77] 폴더 없음: brd865112 (모든 경로 검색 완료)
# ⚠️ [78] 폴더 없음: brd865105 (모든 경로 검색 완료)
# ⚠️ [79] 폴더 없음: brd865104 (모든 경로 검색 완료)
# ⚠️ [80] 폴더 없음: brd865100 (모든 경로 검색 완료)
# ⚠️ [81] 폴더 없음: brd865084 (모든 경로 검색 완료)
# ⚠️ [82] 폴더 없음: brd865080 (모든 경로 검색 완료)
# ⚠️ [83] 폴더 없음: brd865061 (모든 경로 검색 완료)
# ⚠️ [84] 폴더 없음: brd865057 (모든 경로 검색 완료)
# ⚠️ [85] 폴더 없음: brd865036 (모든 경로 검색 완료)
# ⚠️ [86] 폴더 없음: brd865034 (모든 경로 검색 완료)
# ⚠️ [87] 폴더 없음: brd865032 (모든 경로 검색 완료)
# ⚠️ [88] 폴더 없음: brd865031 (모든 경로 검색 완료)
# ⚠️ [89] 폴더 없음: brd865028 (모든 경로 검색 완료)
# ⚠️ [90] 폴더 없음: brd865022 (모든 경로 검색 완료)
# ⚠️ [91] 폴더 없음: brd865017 (모든 경로 검색 완료)
# ⚠️ [92] 폴더 없음: brd865014 (모든 경로 검색 완료)
# ⚠️ [93] 폴더 없음: brd865007 (모든 경로 검색 완료)
# ⚠️ [94] 폴더 없음: brd864990 (모든 경로 검색 완료)
# ⚠️ [95] 폴더 없음: brd864986 (모든 경로 검색 완료)
# ⚠️ [96] 폴더 없음: brd864985 (모든 경로 검색 완료)
# ⚠️ [97] 폴더 없음: brd864983 (모든 경로 검색 완료)
# ⚠️ [98] 폴더 없음: brd864971 (모든 경로 검색 완료)
# ⚠️ [99] 폴더 없음: brd864916 (모든 경로 검색 완료)
# ⚠️ [100] 폴더 없음: brd864888 (모든 경로 검색 완료)
# ⚠️ [101] 폴더 없음: brd864871 (모든 경로 검색 완료)
# ⚠️ [102] 폴더 없음: brd864870 (모든 경로 검색 완료)
# ⚠️ [103] 폴더 없음: brd864865 (모든 경로 검색 완료)
# ⚠️ [104] 폴더 없음: brd864852 (모든 경로 검색 완료)
# ⚠️ [105] 폴더 없음: brd864826 (모든 경로 검색 완료)
# ⚠️ [106] 폴더 없음: brd864761 (모든 경로 검색 완료)
# ⚠️ [107] 폴더 없음: brd864755 (모든 경로 검색 완료)
# ⚠️ [108] 폴더 없음: brd864711 (모든 경로 검색 완료)
# ⚠️ [109] 폴더 없음: brd864682 (모든 경로 검색 완료)
# ⚠️ [110] 폴더 없음: brd864679 (모든 경로 검색 완료)
# ⚠️ [111] 폴더 없음: brd864669 (모든 경로 검색 완료)
# ⚠️ [112] 폴더 없음: brd864667 (모든 경로 검색 완료)
# ⚠️ [113] 폴더 없음: brd864643 (모든 경로 검색 완료)
# ⚠️ [114] 폴더 없음: brd864631 (모든 경로 검색 완료)
# ⚠️ [115] 폴더 없음: brd864591 (모든 경로 검색 완료)
# ⚠️ [116] 폴더 없음: brd864590 (모든 경로 검색 완료)
# ⚠️ [117] 폴더 없음: brd864589 (모든 경로 검색 완료)
# ⚠️ [118] 폴더 없음: brd864532 (모든 경로 검색 완료)
# ⚠️ [119] 폴더 없음: brd864517 (모든 경로 검색 완료)
# ⚠️ [120] 폴더 없음: brd864515 (모든 경로 검색 완료)
# ⚠️ [121] 폴더 없음: brd864479 (모든 경로 검색 완료)
# ⚠️ [122] 폴더 없음: brd864473 (모든 경로 검색 완료)
# ⚠️ [123] 폴더 없음: brd864472 (모든 경로 검색 완료)
# ⚠️ [124] 폴더 없음: brd864471 (모든 경로 검색 완료)
# ⚠️ [125] 폴더 없음: brd864470 (모든 경로 검색 완료)
# ⚠️ [126] 폴더 없음: brd864463 (모든 경로 검색 완료)
# ⚠️ [127] 폴더 없음: brd864454 (모든 경로 검색 완료)
# ⚠️ [128] 폴더 없음: brd864452 (모든 경로 검색 완료)
# ⚠️ [129] 폴더 없음: brd864418 (모든 경로 검색 완료)
# ⚠️ [130] 폴더 없음: brd864412 (모든 경로 검색 완료)
# ⚠️ [131] 폴더 없음: brd864375 (모든 경로 검색 완료)
# ⚠️ [132] 폴더 없음: brd864355 (모든 경로 검색 완료)
# ⚠️ [133] 폴더 없음: brd864332 (모든 경로 검색 완료)
# ⚠️ [134] 폴더 없음: brd864330 (모든 경로 검색 완료)
# ⚠️ [135] 폴더 없음: brd864299 (모든 경로 검색 완료)
# ⚠️ [136] 폴더 없음: brd864285 (모든 경로 검색 완료)
# ⚠️ [137] 폴더 없음: brd864276 (모든 경로 검색 완료)
# ⚠️ [138] 폴더 없음: brd864266 (모든 경로 검색 완료)
# ⚠️ [139] 폴더 없음: brd864265 (모든 경로 검색 완료)
# ⚠️ [140] 폴더 없음: brd864243 (모든 경로 검색 완료)
# ⚠️ [141] 폴더 없음: brd864187 (모든 경로 검색 완료)
# ⚠️ [142] 폴더 없음: brd864177 (모든 경로 검색 완료)
# ⚠️ [143] 폴더 없음: brd864171 (모든 경로 검색 완료)
# ⚠️ [144] 폴더 없음: brd864151 (모든 경로 검색 완료)
# ⚠️ [145] 폴더 없음: brd864130 (모든 경로 검색 완료)
# ⚠️ [146] 폴더 없음: brd864128 (모든 경로 검색 완료)
# ⚠️ [147] 폴더 없음: brd864126 (모든 경로 검색 완료)
# ⚠️ [148] 폴더 없음: brd864125 (모든 경로 검색 완료)
# ⚠️ [149] 폴더 없음: brd864116 (모든 경로 검색 완료)
# ⚠️ [150] 폴더 없음: brd864106 (모든 경로 검색 완료)
# ⚠️ [151] 폴더 없음: brd864064 (모든 경로 검색 완료)
# ⚠️ [152] 폴더 없음: brd864059 (모든 경로 검색 완료)
# ⚠️ [153] 폴더 없음: brd864015 (모든 경로 검색 완료)
# ⚠️ [154] 폴더 없음: brd864003 (모든 경로 검색 완료)
# ⚠️ [155] 폴더 없음: brd864002 (모든 경로 검색 완료)
# ⚠️ [156] 폴더 없음: brd863996 (모든 경로 검색 완료)
# ⚠️ [157] 폴더 없음: brd863949 (모든 경로 검색 완료)
# ⚠️ [158] 폴더 없음: brd863948 (모든 경로 검색 완료)
# ⚠️ [159] 폴더 없음: brd863945 (모든 경로 검색 완료)
# ⚠️ [160] 폴더 없음: brd863939 (모든 경로 검색 완료)
# ⚠️ [161] 폴더 없음: brd863938 (모든 경로 검색 완료)
# ⚠️ [162] 폴더 없음: brd863900 (모든 경로 검색 완료)
# ⚠️ [163] 폴더 없음: brd863887 (모든 경로 검색 완료)
# ⚠️ [164] 폴더 없음: brd863877 (모든 경로 검색 완료)
# ⚠️ [165] 폴더 없음: brd863876 (모든 경로 검색 완료)
# ⚠️ [166] 폴더 없음: brd863875 (모든 경로 검색 완료)
# ⚠️ [167] 폴더 없음: brd863874 (모든 경로 검색 완료)
# ⚠️ [168] 폴더 없음: brd863872 (모든 경로 검색 완료)
# ⚠️ [169] 폴더 없음: brd863870 (모든 경로 검색 완료)
# ⚠️ [170] 폴더 없음: brd863868 (모든 경로 검색 완료)
# ⚠️ [171] 폴더 없음: brd863860 (모든 경로 검색 완료)
# ⚠️ [172] 폴더 없음: brd863852 (모든 경로 검색 완료)
# ⚠️ [173] 폴더 없음: brd863843 (모든 경로 검색 완료)
# ⚠️ [174] 폴더 없음: brd863841 (모든 경로 검색 완료)
# ⚠️ [175] 폴더 없음: brd863837 (모든 경로 검색 완료)
# ⚠️ [176] 폴더 없음: brd863829 (모든 경로 검색 완료)
# ⚠️ [177] 폴더 없음: brd863822 (모든 경로 검색 완료)
# ⚠️ [178] 폴더 없음: brd863797 (모든 경로 검색 완료)
# ⚠️ [179] 폴더 없음: brd863795 (모든 경로 검색 완료)
# ⚠️ [180] 폴더 없음: brd863773 (모든 경로 검색 완료)
# ⚠️ [181] 폴더 없음: brd863765 (모든 경로 검색 완료)
# ⚠️ [182] 폴더 없음: brd863754 (모든 경로 검색 완료)
# ⚠️ [183] 폴더 없음: brd863746 (모든 경로 검색 완료)
# ⚠️ [184] 폴더 없음: brd863701 (모든 경로 검색 완료)
# ⚠️ [185] 폴더 없음: brd863656 (모든 경로 검색 완료)
# ⚠️ [186] 폴더 없음: brd863653 (모든 경로 검색 완료)
# ⚠️ [187] 폴더 없음: brd863652 (모든 경로 검색 완료)
# ⚠️ [188] 폴더 없음: brd863651 (모든 경로 검색 완료)
# ⚠️ [189] 폴더 없음: brd863645 (모든 경로 검색 완료)
# ⚠️ [190] 폴더 없음: brd863638 (모든 경로 검색 완료)
# ⚠️ [191] 폴더 없음: brd863637 (모든 경로 검색 완료)
# ⚠️ [192] 폴더 없음: brd863636 (모든 경로 검색 완료)
# ⚠️ [193] 폴더 없음: brd863595 (모든 경로 검색 완료)
# ⚠️ [194] 폴더 없음: brd863591 (모든 경로 검색 완료)
# ⚠️ [195] 폴더 없음: brd863588 (모든 경로 검색 완료)
# ⚠️ [196] 폴더 없음: brd863583 (모든 경로 검색 완료)
# ⚠️ [197] 폴더 없음: brd863564 (모든 경로 검색 완료)
# ⚠️ [198] 폴더 없음: brd863563 (모든 경로 검색 완료)
# ⚠️ [199] 폴더 없음: brd863561 (모든 경로 검색 완료)
# ⚠️ [200] 폴더 없음: brd863558 (모든 경로 검색 완료)
# ⚠️ [201] 폴더 없음: brd863555 (모든 경로 검색 완료)
# ⚠️ [202] 폴더 없음: brd863535 (모든 경로 검색 완료)
# ⚠️ [203] 폴더 없음: brd863527 (모든 경로 검색 완료)
# ⚠️ [204] 폴더 없음: brd863526 (모든 경로 검색 완료)
# ⚠️ [205] 폴더 없음: brd863525 (모든 경로 검색 완료)
# ⚠️ [206] 폴더 없음: brd863518 (모든 경로 검색 완료)
# ⚠️ [207] 폴더 없음: brd863516 (모든 경로 검색 완료)
# ⚠️ [208] 폴더 없음: brd863477 (모든 경로 검색 완료)
# ⚠️ [209] 폴더 없음: brd863476 (모든 경로 검색 완료)
# ⚠️ [210] 폴더 없음: brd863451 (모든 경로 검색 완료)
# ⚠️ [211] 폴더 없음: brd863449 (모든 경로 검색 완료)
# ⚠️ [212] 폴더 없음: brd863447 (모든 경로 검색 완료)
# ⚠️ [213] 폴더 없음: brd863445 (모든 경로 검색 완료)
# ⚠️ [214] 폴더 없음: brd863443 (모든 경로 검색 완료)
# ⚠️ [215] 폴더 없음: brd863442 (모든 경로 검색 완료)
# ⚠️ [216] 폴더 없음: brd863441 (모든 경로 검색 완료)
# ⚠️ [217] 폴더 없음: brd863439 (모든 경로 검색 완료)
# ⚠️ [218] 폴더 없음: brd863438 (모든 경로 검색 완료)
# ⚠️ [219] 폴더 없음: brd863434 (모든 경로 검색 완료)
# ⚠️ [220] 폴더 없음: brd863433 (모든 경로 검색 완료)
# ⚠️ [221] 폴더 없음: brd863432 (모든 경로 검색 완료)
# ⚠️ [222] 폴더 없음: brd863428 (모든 경로 검색 완료)
# ⚠️ [223] 폴더 없음: brd863426 (모든 경로 검색 완료)
# ⚠️ [224] 폴더 없음: brd863425 (모든 경로 검색 완료)
# ⚠️ [225] 폴더 없음: brd863423 (모든 경로 검색 완료)
# ⚠️ [226] 폴더 없음: brd863417 (모든 경로 검색 완료)
# ⚠️ [227] 폴더 없음: brd863394 (모든 경로 검색 완료)
# ⚠️ [228] 폴더 없음: brd863387 (모든 경로 검색 완료)
# ⚠️ [229] 폴더 없음: brd863377 (모든 경로 검색 완료)
# ⚠️ [230] 폴더 없음: brd863367 (모든 경로 검색 완료)
# ⚠️ [231] 폴더 없음: brd863355 (모든 경로 검색 완료)
# ⚠️ [232] 폴더 없음: brd863354 (모든 경로 검색 완료)
# ⚠️ [233] 폴더 없음: brd863353 (모든 경로 검색 완료)
# ⚠️ [234] 폴더 없음: brd863352 (모든 경로 검색 완료)
# ⚠️ [235] 폴더 없음: brd863351 (모든 경로 검색 완료)
# ⚠️ [236] 폴더 없음: brd863336 (모든 경로 검색 완료)
# ⚠️ [237] 폴더 없음: brd863316 (모든 경로 검색 완료)
# ⚠️ [238] 폴더 없음: brd863311 (모든 경로 검색 완료)
# ⚠️ [239] 폴더 없음: brd863307 (모든 경로 검색 완료)
# ⚠️ [240] 폴더 없음: brd863306 (모든 경로 검색 완료)
# ⚠️ [241] 폴더 없음: brd863297 (모든 경로 검색 완료)
# ⚠️ [242] 폴더 없음: brd863289 (모든 경로 검색 완료)
# ⚠️ [243] 폴더 없음: brd863252 (모든 경로 검색 완료)
# ⚠️ [244] 폴더 없음: brd863251 (모든 경로 검색 완료)
# ⚠️ [245] 폴더 없음: brd863247 (모든 경로 검색 완료)
# ⚠️ [246] 폴더 없음: brd863241 (모든 경로 검색 완료)
# ⚠️ [247] 폴더 없음: brd863238 (모든 경로 검색 완료)
# ⚠️ [248] 폴더 없음: brd863207 (모든 경로 검색 완료)
# ⚠️ [249] 폴더 없음: brd863189 (모든 경로 검색 완료)
# ⚠️ [250] 폴더 없음: brd863188 (모든 경로 검색 완료)
# ⚠️ [251] 폴더 없음: brd863186 (모든 경로 검색 완료)
# ⚠️ [252] 폴더 없음: brd863113 (모든 경로 검색 완료)
# ⚠️ [253] 폴더 없음: brd863112 (모든 경로 검색 완료)
# ⚠️ [254] 폴더 없음: brd863102 (모든 경로 검색 완료)
# ⚠️ [255] 폴더 없음: brd863100 (모든 경로 검색 완료)
# ⚠️ [256] 폴더 없음: brd863095 (모든 경로 검색 완료)
# ⚠️ [257] 폴더 없음: brd863093 (모든 경로 검색 완료)
# ⚠️ [258] 폴더 없음: brd863081 (모든 경로 검색 완료)
# ⚠️ [259] 폴더 없음: brd862998 (모든 경로 검색 완료)
# ⚠️ [260] 폴더 없음: brd862997 (모든 경로 검색 완료)
# ⚠️ [261] 폴더 없음: brd862996 (모든 경로 검색 완료)
# ⚠️ [262] 폴더 없음: brd862995 (모든 경로 검색 완료)
#
# ============================================================
# ✅ 처리 완료!
#    - 게시판 타입: free
#    - 처리된 posts: 21/262개
#    - 복사된 이미지 위치: C:\Users\LEEJUHWAN\Downloads\board_free_img
#    - DB 테이블: board_posts (content 컬럼 업데이트)
# ============================================================
#
# ✅ DB 연결 종료

# %%
#첨부파일 처리 - 파일 복사 및 json path 변경

import json
import os
import shutil
from pathlib import Path

# ==================== 설정 영역 (여기를 수정하세요) ====================

# 첨부파일 원본 경로들 - 여러 경로 추가 가능
BASE_FILE_PATHS = [
    r"C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd",
    r"C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd",
    r"C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd",
    r"C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd",
    # 더 추가하고 싶으면 여기에 계속 추가

]

# 첨부파일 복사본 저장 폴더
OUTPUT_FILE_FOLDER = r"C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments"

# 처리할 JSON 파일
JSON_FILE = r"board_posts_imgConvert.json"

# path에서 제거할 접두사 (이 부분을 제거하고 상대경로로 변경)
REMOVE_PREFIX = r"C:\Users\LEEJUHWAN\Downloads"

# ======================================================================


def find_attachment_folder(board_id):
    """여러 경로에서 게시판 ID에 해당하는 첨부파일 폴더 찾기"""
    for base_path in BASE_FILE_PATHS:
        attachment_folder = Path(base_path) / board_id
        if attachment_folder.exists():
            return attachment_folder
    return None


def find_file_in_folder(folder, filename):
    """폴더 내에서 파일명과 일치하는 파일 찾기 (대소문자 구분 없음)"""
    if not folder or not folder.exists():
        return None
    
    # 정확한 파일명으로 먼저 찾기
    target_file = folder / filename
    if target_file.exists() and target_file.is_file():
        return target_file
    
    # 대소문자 구분 없이 찾기
    for file in folder.iterdir():
        if file.is_file() and file.name.lower() == filename.lower():
            return file
    
    return None


def process_single_post_attachments(data, post_index):
    """하나의 post의 첨부파일 처리"""
    
    # sourceId에서 게시판ID 추출
    source_id = data.get('sourceId', '')
    if not source_id:
        print(f"⚠️ [{post_index}] sourceId 없음, 건너뜀")
        return data
    
    board_id = source_id.lstrip('_')
    
    # attaches 배열 확인
    attaches = data.get('attaches', [])
    if not attaches:
        return data  # 첨부파일 없으면 그대로 반환
    
    # 여러 경로에서 첨부파일 폴더 찾기
    attachment_folder = find_attachment_folder(board_id)
    
    if not attachment_folder:
        print(f"⚠️ [{post_index}] 게시판ID {board_id} 폴더 없음 (모든 경로 검색 완료)")
        # 폴더가 없으면 모든 첨부파일의 path를 공란으로
        for attach in attaches:
            attach['path'] = ''
        return data
    
    # 복사본 저장할 게시판별 폴더 생성
    output_board_folder = Path(OUTPUT_FILE_FOLDER) / f"brd{board_id}"
    output_board_folder.mkdir(parents=True, exist_ok=True)
    
    print(f"\n📄 [{post_index}] 게시판ID: {board_id}")
    print(f"   원본: {attachment_folder}")
    print(f"   복사: {output_board_folder}")
    print(f"   ✅ 첨부파일 {len(attaches)}개 발견")
    
    # 각 첨부파일 처리
    processed_attaches = []
    copied_count = 0
    
    for idx, attach in enumerate(attaches):
        filename = attach.get('name', '')
        if not filename:
            print(f"      ⚠️ [{idx}] 파일명 없음 - path 공란 처리")
            attach['path'] = ''
            processed_attaches.append(attach)
            continue
        
        # 원본 폴더에서 파일 찾기
        source_file = find_file_in_folder(attachment_folder, filename)
        
        if source_file:
            # 복사본 파일 경로
            dest_file = output_board_folder / filename
            
            # 파일 복사
            try:
                shutil.copy2(source_file, dest_file)
                copied_count += 1
                print(f"      ✅ {filename}")
                
                # path를 상대경로로 변경 (REMOVE_PREFIX 제거)
                new_path = str(dest_file).replace('\\', '/')
                if REMOVE_PREFIX:
                    new_path = new_path.replace(REMOVE_PREFIX.replace('\\', '/'), '').lstrip('/')
                    new_path = new_path.replace(REMOVE_PREFIX, '').lstrip('\\')
                
                attach['path'] = new_path
                
            except Exception as e:
                print(f"      ❌ {filename} 복사 실패: {e}")
                attach['path'] = ''
        else:
            print(f"      ⚠️ 파일 없음: {filename} - path 공란 처리")
            attach['path'] = ''
        
        processed_attaches.append(attach)
    
    print(f"   📊 복사 완료: {copied_count}/{len(attaches)}개")
    
    # 수정된 attaches 적용
    data['attaches'] = processed_attaches
    return data


def process_json_file(json_file_path):
    """JSON 파일 처리"""
    
    # 출력 폴더 생성
    os.makedirs(OUTPUT_FILE_FOLDER, exist_ok=True)
    
    # 1. JSON 파일 읽기
    print(f"📂 파일 읽는 중: {json_file_path}")
    print(f"📂 검색할 첨부파일 경로: {len(BASE_FILE_PATHS)}개\n")
    
    with open(json_file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    posts = data.get('posts', [])
    total_count = len(posts)
    
    print(f"✅ 총 {total_count}개의 posts 발견\n")
    
    # 2. 각 post 처리
    processed_posts = []
    success_count = 0
    total_attachments = 0
    
    for idx, post in enumerate(posts, 1):
        try:
            # 첨부파일이 있는 경우만 카운트
            if post.get('attaches'):
                total_attachments += len(post.get('attaches'))
            
            result = process_single_post_attachments(post, idx)
            processed_posts.append(result)
            
            if result != post:  # 변경사항이 있으면
                success_count += 1
        except Exception as e:
            print(f"❌ [Post {idx}] 처리 오류: {e}")
            processed_posts.append(post)  # 오류 시 원본 유지
            continue
    
    # 3. 수정된 데이터 저장
    output_file = json_file_path.replace('.json', '_attachConvert.json')
    
    output_data = {"posts": processed_posts}
    
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(output_data, f, ensure_ascii=False, indent=2)
    
    print(f"\n{'='*60}")
    print(f"✅ 처리 완료!")
    print(f"   - 첨부파일 있는 posts: {success_count}개")
    print(f"   - 총 첨부파일 개수: {total_attachments}개")
    print(f"   - 복사된 파일 위치: {OUTPUT_FILE_FOLDER}")
    print(f"   - 수정된 JSON 파일: {output_file}")
    print(f"{'='*60}")


# 실행
if __name__ == "__main__":
    process_json_file(JSON_FILE)
# Out:
# 📂 파일 읽는 중: board_posts_imgConvert.json
# 📂 검색할 첨부파일 경로: 4개
#
# ✅ 총 78개의 posts 발견
#
#
# 📄 [1] 게시판ID: 3667527
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3667527
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd3667527
#    ✅ 첨부파일 2개 발견
#       ✅ (양식)VRB_영업계획보고서_20210520.pptx
#       ✅ (양식)VRB_사업범위체크리스트_20230825.pptx
#    📊 복사 완료: 2/2개
#
# 📄 [2] 게시판ID: 3660541
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3660541
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd3660541
#    ✅ 첨부파일 1개 발견
#       ✅ Project 이행가이드.docx
#    📊 복사 완료: 1/1개
#
# 📄 [3] 게시판ID: 3198720
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3198720
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd3198720
#    ✅ 첨부파일 1개 발견
#       ✅ (양식) 입찰 시 제출서류 요청리스트_0616(요청날짜)_팀_담당자.xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [4] 게시판ID: 3184249
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3184249
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd3184249
#    ✅ 첨부파일 1개 발견
#       ✅ (양식)VRB_영업계획보고서_20210520.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [5] 게시판ID: 3179165
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3179165
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd3179165
#    ✅ 첨부파일 1개 발견
#       ✅ (양식)PJT진척_보고서_20210511.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [6] 게시판ID: 3179163
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3179163
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd3179163
#    ✅ 첨부파일 1개 발견
#       ✅ (양식)PJT종료_보고서_20210511.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [7] 게시판ID: 3179158
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3179158
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd3179158
#    ✅ 첨부파일 1개 발견
#       ✅ (양식)과제개발_계획서_20210511.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [8] 게시판ID: 3179156
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3179156
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd3179156
#    ✅ 첨부파일 1개 발견
#       ✅ (양식)고객명_과제명_제안서_YYYYMMDD.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [9] 게시판ID: 3179155
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3179155
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd3179155
#    ✅ 첨부파일 1개 발견
#       ✅ (양식)문서작성 및 보고서_양식모음(20210501).pptx
#    📊 복사 완료: 1/1개
#
# 📄 [10] 게시판ID: 3119196
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3119196
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd3119196
#    ✅ 첨부파일 1개 발견
#       ✅ (양식)과제보고서(영업-계획-중간-종료)_20210128.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [11] 게시판ID: 3104118
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3104118
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd3104118
#    ✅ 첨부파일 1개 발견
#       ✅ (양식)_고객명_과제관리시스템 Kick Off 보고_YYYYMMDD.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [12] 게시판ID: 3104116
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3104116
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd3104116
#    ✅ 첨부파일 1개 발견
#       ✅ (양식)고객명_과제명_제안서_YYYYMMDD.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [13] 게시판ID: 3104115
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3104115
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd3104115
#    ✅ 첨부파일 1개 발견
#       ✅ (양식)문서작성 및 보고서_양식모음(20210101).pptx
#    📊 복사 완료: 1/1개
#
# 📄 [14] 게시판ID: 3071630
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\3071630
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd3071630
#    ✅ 첨부파일 1개 발견
#       ✅ 과제추진계획서(양식)_20201109.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [15] 게시판ID: 2978186
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2978186
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd2978186
#    ✅ 첨부파일 3개 발견
#       ✅ OOO_OOO프로젝트_진척현황_작성자_YYYYMMDD.pptx
#       ✅ SW개발방법론 표준가이드(사회보장정보원).zip
#       ✅ 프로젝트 표준산출물 (템플릿)-v1.0-20200623_20220225수정.zip
#    📊 복사 완료: 3/3개
#
# 📄 [16] 게시판ID: 2855058
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2855058
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd2855058
#    ✅ 첨부파일 1개 발견
#       ✅ 업무보고서(사내용)_양식표준_20200101.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [17] 게시판ID: 2854609
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2854609
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd2854609
#    ✅ 첨부파일 2개 발견
#       ✅ 업무보고서(사내용)_양식표준_20190530.pptx
#       ✅ 업무보고서(사내용)_양식표준_20190530.pptx
#    📊 복사 완료: 2/2개
#
# 📄 [18] 게시판ID: 2722655
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2722655
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd2722655
#    ✅ 첨부파일 1개 발견
#       ✅ 업무보고서(외부용)_양식표준_20190530.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [19] 게시판ID: 2722633
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2722633
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd2722633
#    ✅ 첨부파일 1개 발견
#       ✅ 업무보고서(사내용)_양식표준_20190530.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [20] 게시판ID: 2722578
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2722578
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd2722578
#    ✅ 첨부파일 1개 발견
#       ✅ (최종)ANYFIVE_AAA고객_시스템명_견적서(YYYYMMDD).xls
#    📊 복사 완료: 1/1개
#
# 📄 [21] 게시판ID: 2677370
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2677370
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd2677370
#    ✅ 첨부파일 2개 발견
#       ✅ 과제명_과제추진계획서_20190303(보고자).pptx
#       ✅ 사업추진현황(신사업팀)_20190301.xlsx
#    📊 복사 완료: 2/2개
#
# 📄 [22] 게시판ID: 2672799
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2672799
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd2672799
#    ✅ 첨부파일 2개 발견
#       ✅ OOO_OOO프로젝트_진척현황_작성자_YYYYMMDD.pptx
#       ✅ 솔루션 프로젝트 이행방안_20200501.pptx
#    📊 복사 완료: 2/2개
#
# 📄 [26] 게시판ID: 2501663
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2501663
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd2501663
#    ✅ 첨부파일 1개 발견
#       ✅ (고객명) 프로젝트 명_프로젝트 WBS v3.0_20180719.xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [27] 게시판ID: 2491379
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2491379
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd2491379
#    ✅ 첨부파일 1개 발견
#       ✅ 2018년_6월_사업실적보고_ooo사업부(20180709).pptx
#    📊 복사 완료: 1/1개
#
# 📄 [28] 게시판ID: 2208057
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2208057
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd2208057
#    ✅ 첨부파일 2개 발견
#       ✅ 월간업무보고_1) 인력 투입 계획 대비 실적.pptx
#       ✅ (고객사) 프로젝트명_인력투입 현황_20170525.xlsx
#    📊 복사 완료: 2/2개
#
# 📄 [29] 게시판ID: 2193746
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2193746
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd2193746
#    ✅ 첨부파일 3개 발견
#       ✅ SVN 및 DB 양식.txt
#       ✅ 결함관리대장_v1.0.xlsx
#       ✅ SVN 및 DB 샘플.png
#    📊 복사 완료: 3/3개
#
# 📄 [30] 게시판ID: 2190640
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2190640
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd2190640
#    ✅ 첨부파일 2개 발견
#       ✅ A4횡_PPT_PT용자료(양식A)_20170301.pptx
#       ✅ A4횡_PPT_PT용자료(양식B)_20170301.pptx
#    📊 복사 완료: 2/2개
#
# 📄 [33] 게시판ID: 865508
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865508
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865508
#    ✅ 첨부파일 1개 발견
#       ✅ (양식)VRB_20150810_프로젝트명.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [34] 게시판ID: 865470
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865470
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865470
#    ✅ 첨부파일 1개 발견
#       ✅ (양식)VRB_20150810_프로젝트명.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [35] 게시판ID: 865457
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865457
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865457
#    ✅ 첨부파일 1개 발견
#       ✅ ETRI_R&BD3차_PMS고도화_진척보고_v1.0(20150708).pptx
#    📊 복사 완료: 1/1개
#
# 📄 [36] 게시판ID: 865418
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865418
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865418
#    ✅ 첨부파일 1개 발견
#       ✅ [착수보고서]고객명_사업명_착수보고서_20150415.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [37] 게시판ID: 865416
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865416
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865416
#    ✅ 첨부파일 1개 발견
#       ✅ 양식_사내보고문서(20150415).pptx
#    📊 복사 완료: 1/1개
#
# 📄 [38] 게시판ID: 865413
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865413
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865413
#    ✅ 첨부파일 1개 발견
#       ✅ 과제추진계획서_R_과제명_YYYYMMDD(성명).ppt
#    📊 복사 완료: 1/1개
#
# 📄 [39] 게시판ID: 865405
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865405
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865405
#    ✅ 첨부파일 1개 발견
#       ✅ 프로젝트_진척현황(YYYYMMDD).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [40] 게시판ID: 865337
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865337
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865337
#    ✅ 첨부파일 2개 발견
#       ✅ A4횡_주간업무보고서양식_20150122.pptx
#       ✅ A4종_주간업무보고서양식_20150122.pptx
#    📊 복사 완료: 2/2개
#
# 📄 [41] 게시판ID: 865335
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865335
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865335
#    ✅ 첨부파일 1개 발견
#       ✅ 소싱요청 양식.docx
#    📊 복사 완료: 1/1개
#
# 📄 [42] 게시판ID: 865334
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865334
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865334
#    ✅ 첨부파일 1개 발견
#       ✅ PM2110_회의록 v1.0.doc
#    📊 복사 완료: 1/1개
#
# 📄 [43] 게시판ID: 865333
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865333
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865333
#    ✅ 첨부파일 1개 발견
#       ✅ P1370_프로젝트계획서 붙임_투입인력관리대장 v1.2.xls
#    📊 복사 완료: 1/1개
#
# 📄 [44] 게시판ID: 865332
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865332
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865332
#    ✅ 첨부파일 1개 발견
#       ✅ A4횡_월간업무보고서양식_20150116.pptx
#    📊 복사 완료: 1/1개
#
# 📄 [45] 게시판ID: 865331
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865331
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865331
#    ✅ 첨부파일 2개 발견
#       ✅ A4종_주간업무보고서양식_20150107.pptx
#       ✅ A4횡_주간업무보고서양식_20150116.pptx
#    📊 복사 완료: 2/2개
#
# 📄 [46] 게시판ID: 865325
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865325
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865325
#    ✅ 첨부파일 2개 발견
#       ✅ (완료보고-IPIMS)_고객명_BBB(IPIMS)_완료보고_20150107.pptx
#       ✅ (완료보고-SI)_고객명_BBB시스템_완료보고_20150107.pptx
#    📊 복사 완료: 2/2개
#
# 📄 [47] 게시판ID: 865324
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865324
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865324
#    ✅ 첨부파일 2개 발견
#       ✅ (진척보고-IPIMS)_고객명_BBB시스템_중간진척보고_20150107.pptx
#       ✅ (진척보고-SI)_고객명_BBB시스템_중간진척보고_20150107.pptx
#    📊 복사 완료: 2/2개
#
# 📄 [48] 게시판ID: 865310
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865310
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865310
#    ✅ 첨부파일 1개 발견
#       ✅ 특허출원제안서_XML 기반의 전자연구노트(20091201).ppt
#    📊 복사 완료: 1/1개
#
# 📄 [49] 게시판ID: 865309
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865309
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865309
#    ✅ 첨부파일 1개 발견
#       ✅ 특허출원제안서_데이터셋기반의_화면처리방식(20091201).ppt
#    📊 복사 완료: 1/1개
#
# 📄 [51] 게시판ID: 865256
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865256
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865256
#    ✅ 첨부파일 3개 발견
#       ✅ ANYFIVE_표준견적서_솔루션(20141001).xls
#       ✅ ANYFIVE_표준견적서_도급(20141001).xls
#       ✅ ANYFIVE_표준견적서_유지보수(20141001).xls
#    📊 복사 완료: 3/3개
#
# 📄 [52] 게시판ID: 865250
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865250
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865250
#    ✅ 첨부파일 2개 발견
#       ✅ ANYFIVE_경력기술서_홍길동(YYYYMMDD).doc
#       ✅ ANYFIVE_경력기술서(R)_홍길동(YYYYMMDD).doc
#    📊 복사 완료: 2/2개
#
# 📄 [54] 게시판ID: 865248
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865248
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865248
#    ✅ 첨부파일 1개 발견
#       ✅ (양식)_스크럼보드_작성템플릿_20120101.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [55] 게시판ID: 865247
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865247
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865247
#    ✅ 첨부파일 2개 발견
#       ✅ 03_050428_Process Set PI방법론_사업부 설명용.ppt
#       ✅ 특허프로세스정립_샘플(20141001).ppt
#    📊 복사 완료: 2/2개
#
# 📄 [56] 게시판ID: 865241
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865241
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865241
#    ✅ 첨부파일 1개 발견
#       ✅ (프로그램 개발 일정표) xxx프로젝트_20110406.xls
#    📊 복사 완료: 1/1개
#
# 📄 [57] 게시판ID: 865240
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865240
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865240
#    ✅ 첨부파일 1개 발견
#       ✅ 고객명_PJT명_요구사항정의분석서(YYYYMMDD).xls
#    📊 복사 완료: 1/1개
#
# 📄 [59] 게시판ID: 865237
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865237
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865237
#    ✅ 첨부파일 2개 발견
#       ✅ AWM_WEB 개발방법론.pdf
#       ✅ APM_프로젝트 관리방법론.pdf
#    📊 복사 완료: 2/2개
#
# 📄 [60] 게시판ID: 865236
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865236
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865236
#    ✅ 첨부파일 1개 발견
#       ✅ ANYFIVE_PM 테일러링 가이드_20130426.xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [61] 게시판ID: 865233
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865233
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865233
#    ✅ 첨부파일 2개 발견
#       ✅ ANYFIVE_WEB 기법.zip
#       ✅ ANYFIVE_PM 기법.zip
#    📊 복사 완료: 2/2개
#
# 📄 [62] 게시판ID: 865232
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865232
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865232
#    ✅ 첨부파일 4개 발견
#       ✅ EQA_P01_T03_전사_품질보증_점검표(품질관리-ISP).xls
#       ✅ APM AWM_PM_WEB(IE)_프로젝트_품질보증_체크리스트_1.0(20140402).xls
#       ✅ EQA_P01_T01_전사_품질보증_점검표(품질관리-프로젝트관리 및 품질보증).xls
#       ✅ EQA_P01_T02_전사_품질보증_점검표(품질관리-시스템개발).xls
#    📊 복사 완료: 4/4개
#
# 📄 [63] 게시판ID: 865231
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865231
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865231
#    ✅ 첨부파일 2개 발견
#       ✅ (Kickoff-SI과제)-고객명_BBB시스템_Kickoff_20140813.ppt
#       ✅ (Kickoff-IPIMS)-고객명_BBB(IPIMS)_Kickoff_20140813.ppt
#    📊 복사 완료: 2/2개
#
# 📄 [64] 게시판ID: 865230
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865230
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865230
#    ✅ 첨부파일 1개 발견
#       ✅ (완료보고-IPIMS)_고객명_BBB(IPIMS)_완료보고_20140814.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [65] 게시판ID: 865229
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865229
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865229
#    ✅ 첨부파일 1개 발견
#       ✅ 고객명_특허시스템구축_구축범위_공수산정_20120101.xls
#    📊 복사 완료: 1/1개
#
# 📄 [66] 게시판ID: 865228
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865228
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd865228
#    ✅ 첨부파일 2개 발견
#       ✅ (진척보고-IPIMS)_고객명_BBB(IPIMS)_중간진척보고_20140814.ppt
#       ✅ (진척보고-SI)_고객명_BBB시스템_중간진척보고_20140814.ppt
#    📊 복사 완료: 2/2개
#
# 📄 [67] 게시판ID: 864213
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864213
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd864213
#    ✅ 첨부파일 1개 발견
#       ✅ (양식B-PT)_ANYFIVE_문서표준양식_템플릿모음_20120314.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [68] 게시판ID: 864170
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864170
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd864170
#    ✅ 첨부파일 1개 발견
#       ✅ (양식A-보고)_ANYFIVE_문서표준양식_템플릿모음_20120101(1).ppt
#    📊 복사 완료: 1/1개
#
# 📄 [69] 게시판ID: 864169
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864169
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd864169
#    ✅ 첨부파일 1개 발견
#       ✅ [문서참조-공공] 창진원녹십자_R&D_제안서_20120201.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [70] 게시판ID: 864148
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864148
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd864148
#    ✅ 첨부파일 1개 발견
#       ✅ (PT용)전자연구노트(Smartlab)소개_(20120210)_Upload.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [71] 게시판ID: 864145
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864145
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd864145
#    ✅ 첨부파일 1개 발견
#       ✅ 01.(진척보고-SI)_하이닉스_특허평가분석체계구축_중간진척보고_20120203.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [72] 게시판ID: 864144
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864144
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd864144
#    ✅ 첨부파일 1개 발견
#       ✅ (진척보고-SI)_고객명_BBB시스템_중간진척보고_20120101(2)(3).ppt
#    📊 복사 완료: 1/1개
#
# 📄 [73] 게시판ID: 864142
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864142
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd864142
#    ✅ 첨부파일 1개 발견
#       ✅ (완료보고-IPIMS)_고객명_BBB(IPIMS)_완료보고_20120101.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [74] 게시판ID: 864141
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864141
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd864141
#    ✅ 첨부파일 1개 발견
#       ✅ (진척보고-IPIMS)_고객명_BBB(IPIMS)_중간진척보고_20120101.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [75] 게시판ID: 864140
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864140
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd864140
#    ✅ 첨부파일 1개 발견
#       ✅ (Kickoff-Smartlab)_고객명_BBB(SmartLab)_Kickoff_20120101.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [76] 게시판ID: 864139
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864139
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd864139
#    ✅ 첨부파일 1개 발견
#       ✅ (Kickoff-SI과제)-고객명_BBB시스템_Kickoff_20120101.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [77] 게시판ID: 864138
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864138
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd864138
#    ✅ 첨부파일 1개 발견
#       ✅ (Kickoff-IPIMS)-고객명_BBB(IPIMS)_Kickoff_20120101.ppt
#    📊 복사 완료: 1/1개
#
# 📄 [78] 게시판ID: 864137
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\864137
#    복사: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments\brd864137
#    ✅ 첨부파일 1개 발견
#       ✅ (테스트)_IPIMS솔루션_통합테스트케이스_20120101.xls
#    📊 복사 완료: 1/1개
#
# ============================================================
# ✅ 처리 완료!
#    - 첨부파일 있는 posts: 0개
#    - 총 첨부파일 개수: 95개
#    - 복사된 파일 위치: C:\Users\LEEJUHWAN\Downloads\board_docForm_attachments
#    - 수정된 JSON 파일: board_posts_imgConvert_attachConvert.json
# ============================================================

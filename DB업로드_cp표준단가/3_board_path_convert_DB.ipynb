# %%
# 첨부파일 경로 변환 - DB 직접 연동 버전
# type 컬럼으로 게시판 선택

import json
import os
import shutil
from pathlib import Path
import pymysql
from sqlalchemy import create_engine

# ==================== DB 설정 ====================
USER = "root"
PASS = "1234"
HOST = "127.0.0.1"
PORT = 3306
DB = "crawling"

# ==================== 설정 영역 (여기를 수정하세요) ====================

# 게시판 타입 (필터링용)
BOARD_TYPE = "cp"  # ✨ 추가: hredu, cp, sales 등

# 첨부파일 원본 경로들 - 여러 경로 추가 가능
BASE_FILE_PATHS = [
    r"C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd",
    r"C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd",
    r"C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd",
    r"C:\Users\LEEJUHWAN\Downloads\2010-01-01~2010-12-31\html\resource\file\brd",
    # 더 추가하고 싶으면 여기에 계속 추가
]

# 첨부파일 복사본 저장 폴더 (타입별로 자동 생성)
OUTPUT_FILE_FOLDER = rf"C:\Users\LEEJUHWAN\Downloads\board_{BOARD_TYPE}_attachments"  # ✨ 타입 반영

# path에서 제거할 접두사 (이 부분을 제거하고 상대경로로 변경)
REMOVE_PREFIX = r"C:\Users\LEEJUHWAN\Downloads"

# ======================================================================


def find_attachment_folder(board_id):
    """여러 경로에서 첨부파일 폴더 찾기"""
    for base_path in BASE_FILE_PATHS:
        attachment_folder = Path(base_path) / board_id
        if attachment_folder.exists():
            return attachment_folder
    return None


def find_file_in_folder(folder, filename):
    """폴더 내에서 파일명과 일치하는 파일 찾기 (대소문자 구분 없음)"""
    if not folder or not folder.exists():
        return None
    
    # 정확한 파일명으로 먼저 찾기
    target_file = folder / filename
    if target_file.exists() and target_file.is_file():
        return target_file
    
    # 대소문자 구분 없이 찾기
    for file in folder.iterdir():
        if file.is_file() and file.name.lower() == filename.lower():
            return file
    
    return None


def process_single_post_attachments(data, post_index):
    """하나의 post의 첨부파일 처리"""
    
    # sourceId에서 게시판ID 추출
    source_id = data.get('sourceId', '')
    if not source_id:
        print(f"⚠️ [{post_index}] sourceId 없음, 건너뜀")
        return data
    
    board_id = source_id.lstrip('_')
    
    # attaches 배열 확인
    attaches = data.get('attaches', [])
    if not attaches:
        return data  # 첨부파일 없으면 그대로 반환
    
    # 여러 경로에서 첨부파일 폴더 찾기
    attachment_folder = find_attachment_folder(board_id)
    
    if not attachment_folder:
        print(f"⚠️ [{post_index}] 게시판ID {board_id} 폴더 없음 (모든 경로 검색 완료)")
        # 폴더가 없으면 모든 첨부파일의 path를 공란으로
        for attach in attaches:
            attach['path'] = ''
        return data
    
    # 복사본 저장할 게시판별 폴더 생성
    output_board_folder = Path(OUTPUT_FILE_FOLDER) / f"brd{board_id}"
    output_board_folder.mkdir(parents=True, exist_ok=True)
    
    print(f"\n📄 [{post_index}] 게시판ID: {board_id}")
    print(f"   원본: {attachment_folder}")
    print(f"   복사: {output_board_folder}")
    print(f"   ✅ 첨부파일 {len(attaches)}개 발견")
    
    # 각 첨부파일 처리
    processed_attaches = []
    copied_count = 0
    
    for idx, attach in enumerate(attaches):
        filename = attach.get('name', '')
        if not filename:
            print(f"      ⚠️ [{idx}] 파일명 없음 - path 공란 처리")
            attach['path'] = ''
            processed_attaches.append(attach)
            continue
        
        # 원본 폴더에서 파일 찾기
        source_file = find_file_in_folder(attachment_folder, filename)
        
        if source_file:
            # 복사본 파일 경로
            dest_file = output_board_folder / filename
            
            # 파일 복사
            try:
                shutil.copy2(source_file, dest_file)
                copied_count += 1
                print(f"      ✅ {filename}")
                
                # path를 상대경로로 변경 (REMOVE_PREFIX 제거)
                new_path = str(dest_file).replace('\\', '/')
                if REMOVE_PREFIX:
                    new_path = new_path.replace(REMOVE_PREFIX.replace('\\', '/'), '').lstrip('/')
                    new_path = new_path.replace(REMOVE_PREFIX, '').lstrip('\\')
                
                attach['path'] = new_path
                
            except Exception as e:
                print(f"      ❌ {filename} 복사 실패: {e}")
                attach['path'] = ''
        else:
            print(f"      ⚠️ 파일 없음: {filename} - path 공란 처리")
            attach['path'] = ''
        
        processed_attaches.append(attach)
    
    print(f"   📊 복사 완료: {copied_count}/{len(attaches)}개")
    
    # 수정된 attaches 적용
    data['attaches'] = processed_attaches
    return data


def process_db(board_type):
    """DB에서 특정 type의 데이터만 읽고 처리 후 DB에 업데이트"""
    
    # 출력 폴더 생성
    os.makedirs(OUTPUT_FILE_FOLDER, exist_ok=True)
    
    # DB 연결
    print(f"📂 DB 연결 중...")
    print(f"📂 게시판 타입: {board_type}")  # ✨ 추가
    print(f"📂 검색할 첨부파일 경로: {len(BASE_FILE_PATHS)}개\n")
    
    connection = pymysql.connect(
        host=HOST,
        user=USER,
        password=PASS,
        database=DB,
        port=PORT,
        charset='utf8mb4'
    )
    
    try:
        with connection.cursor(pymysql.cursors.DictCursor) as cursor:
            # 1. DB에서 특정 type의 데이터만 읽기
            query = "SELECT * FROM board_posts WHERE type = %s"  # ✨ WHERE 조건 추가
            cursor.execute(query, (board_type,))
            posts = cursor.fetchall()
            
            total_count = len(posts)
            print(f"✅ 총 {total_count}개의 posts 발견\n")
            
            # 2. 각 post 처리
            success_count = 0
            total_attachments = 0
            
            for idx, post in enumerate(posts, 1):
                try:
                    # attaches_json을 파싱하여 attaches로 변환
                    if post.get('attaches_json'):
                        post['attaches'] = json.loads(post['attaches_json'])
                    else:
                        post['attaches'] = []
                    
                    # 첨부파일이 있는 경우만 카운트
                    if post.get('attaches'):
                        total_attachments += len(post.get('attaches'))
                    
                    # 기존 로직 그대로 사용
                    result = process_single_post_attachments(post, idx)
                    
                    # attaches가 변경된 경우 DB 업데이트
                    if result.get('attaches'):
                        # attaches를 JSON 문자열로 변환
                        attaches_json = json.dumps(result['attaches'], ensure_ascii=False)
                        
                        update_query = """
                            UPDATE board_posts 
                            SET attaches_json = %s 
                            WHERE sourceId = %s AND type = %s
                        """  # ✨ WHERE 조건에 type도 추가
                        cursor.execute(update_query, (attaches_json, result['sourceId'], board_type))
                        success_count += 1
                    
                except Exception as e:
                    print(f"❌ [Post {idx}] 처리 오류: {e}")
                    continue
            
            # 변경사항 커밋
            connection.commit()
            
            print(f"\n{'='*60}")
            print(f"✅ 처리 완료!")
            print(f"   - 게시판 타입: {board_type}")  # ✨ 추가
            print(f"   - 첨부파일 있는 posts: {success_count}개")
            print(f"   - 총 첨부파일 개수: {total_attachments}개")
            print(f"   - 복사된 파일 위치: {OUTPUT_FILE_FOLDER}")
            print(f"   - DB 테이블: board_posts (attaches_json 컬럼 업데이트)")
            print(f"{'='*60}")
    
    finally:
        connection.close()
        print("\n✅ DB 연결 종료")


# 실행
if __name__ == "__main__":
    process_db(BOARD_TYPE)  # ✨ board_type 인자 추가
# Out:
# 📂 DB 연결 중...
# 📂 게시판 타입: cp
# 📂 검색할 첨부파일 경로: 4개
#
# ✅ 총 31개의 posts 발견
#
#
# 📄 [1] 게시판ID: 4044776
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\4044776
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd4044776
#    ✅ 첨부파일 1개 발견
#       ✅ PJT_CODE_(고객명)+사업명(YYYYMMDD_YYYYMMDD)_20241201(V7.0).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [2] 게시판ID: 3992142
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3992142
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd3992142
#    ✅ 첨부파일 1개 발견
#       ✅ PJT_CODE_(고객명)+사업명(YYYYMMDD_YYYYMMDD)_20241201(V7.0).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [3] 게시판ID: 3883988
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3883988
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd3883988
#    ✅ 첨부파일 1개 발견
#       ✅ PJT_CODE_(고객명)+사업명(YYYYMMDD_YYYYMMDD)_20240801(V6.11).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [4] 게시판ID: 3857977
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3857977
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd3857977
#    ✅ 첨부파일 1개 발견
#       ✅ PJT_CODE_(고객명)+사업명(YYYYMMDD_YYYYMMDD)_20240701(V6.01).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [5] 게시판ID: 3735703
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3735703
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd3735703
#    ✅ 첨부파일 1개 발견
#       ✅ PJT_CODE_(고객명)+사업명(YYYYMMDD_YYYYMMDD)_20240101(V6.0).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [6] 게시판ID: 3528840
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3528840
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd3528840
#    ✅ 첨부파일 1개 발견
#       ✅ PJT_CODE_(고객명)+사업명(YYYYMMDD_YYYYMMDD)_20230201(V5.02).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [7] 게시판ID: 3515939
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3515939
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd3515939
#    ✅ 첨부파일 1개 발견
#       ✅ PJT_CODE_(고객명)+사업명(YYYYMMDD_YYYYMMDD)_20230101(V5.01).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [8] 게시판ID: 3505086
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3505086
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd3505086
#    ✅ 첨부파일 1개 발견
#       ✅ PJT_CODE_(고객명)+사업명(YYYYMMDD_YYYYMMDD)_20221201(V5.0).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [9] 게시판ID: 3484820
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3484820
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd3484820
#    ✅ 첨부파일 1개 발견
#       ✅ PJT_CODE_(고객명)+사업명(YYYYMMDD_YYYYMMDD)_20221201(V4.42).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [10] 게시판ID: 3338503
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3338503
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd3338503
#    ✅ 첨부파일 1개 발견
#       ✅ PJT_CODE_(고객명)+사업명(YYYYMMDD_YYYYMMDD)_20220218(V4.41).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [11] 게시판ID: 3250890
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3250890
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd3250890
#    ✅ 첨부파일 1개 발견
#       ✅ PJT_CODE_(고객명)+사업명(YYYYMMDD_YYYYMMDD)_20210901(V4.2).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [12] 게시판ID: 3175709
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3175709
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd3175709
#    ✅ 첨부파일 1개 발견
#       ✅ PJT_CODE_(고객명)+사업명(YYYYMMDD_YYYYMMDD)_20210501(V4.1).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [13] 게시판ID: 3147559
#    원본: C:\Users\LEEJUHWAN\Downloads\2021-01-01~2025-10-31\html\resource\file\brd\3147559
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd3147559
#    ✅ 첨부파일 1개 발견
#       ✅ PJT_CODE_(고객명)+사업명(YYYYMMDD_YYYYMMDD)_20210201(V4.0).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [14] 게시판ID: 3045884
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\3045884
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd3045884
#    ✅ 첨부파일 1개 발견
#       ✅ (고객명) 프로젝트명_손익관리(인건비)_v1.5(CP Ver 3.3.1)_최종.xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [15] 게시판ID: 2854043
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2854043
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd2854043
#    ✅ 첨부파일 1개 발견
#       ✅ PRJ_CODE_(고객명)+사업명(YYYYMMDD~YYYYMMDD)_20200101(V3.3.1).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [17] 게시판ID: 2820883
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2820883
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd2820883
#    ✅ 첨부파일 1개 발견
#       ✅ PRJ_CODE_(고객명)+사업명(YYYYMMDD~YYYYMMDD)_20191101(V3.3).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [18] 게시판ID: 2684415
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2684415
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd2684415
#    ✅ 첨부파일 1개 발견
#       ✅ PRJ_CODE_(고객명)+사업명(YYYYMMDD~YYYYMMDD)_20190401(V3.2).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [19] 게시판ID: 2611162
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2611162
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd2611162
#    ✅ 첨부파일 1개 발견
#       ✅ PRJ_CODE_(고객명)+사업명(YYYYMMDD~YYYYMMDD)_20190101(V3.2).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [20] 게시판ID: 2558444
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2558444
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd2558444
#    ✅ 첨부파일 1개 발견
#       ✅ PRJ_CODE_(고객명)+사업명(YYYYMMDD~YYYYMMDD)_20181001(V3.1.1).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [21] 게시판ID: 2542695
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2542695
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd2542695
#    ✅ 첨부파일 1개 발견
#       ✅ PRJ_CODE_(고객명)+사업명(YYYYMMDD~YYYYMMDD)_20180901(V3.1).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [23] 게시판ID: 2449233
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2449233
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd2449233
#    ✅ 첨부파일 1개 발견
#       ✅ PRJ_CODE_(고객명)+사업명(YYYYMMDD~YYYYMMDD)_20180420(V3.0)_최종.xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [24] 게시판ID: 2449192
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2449192
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd2449192
#    ✅ 첨부파일 1개 발견
#       ✅ 2018인건비표준단가표_20180901.JPG
#    📊 복사 완료: 1/1개
#
# 📄 [25] 게시판ID: 2196126
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2196126
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd2196126
#    ✅ 첨부파일 1개 발견
#       ✅ PRJ_CODE_(고객명)+사업명(YYYYMMDD~YYYYMMDD)_20170301(V2.0).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [26] 게시판ID: 2157386
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\2157386
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd2157386
#    ✅ 첨부파일 1개 발견
#       ✅ PRJ_CODE_(고객명)+사업명(YYYYMMDD~YYYYMMDD)_20170106(V1.2).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [27] 게시판ID: 1923281
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\1923281
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd1923281
#    ✅ 첨부파일 1개 발견
#       ✅ PRJ_CODE_(고객명)+사업명(YYYYMMDD~YYYYMMDD)_20160801(V1.1).xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [28] 게시판ID: 1923059
#    원본: C:\Users\LEEJUHWAN\Downloads\2016-01-01~2020-12-31\html\resource\file\brd\1923059
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd1923059
#    ✅ 첨부파일 1개 발견
#       ✅ 2016년_인건비-원가-판가테이블(20160701)_확정.pdf
#    📊 복사 완료: 1/1개
#
# 📄 [29] 게시판ID: 865541
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865541
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd865541
#    ✅ 첨부파일 1개 발견
#       ✅ CP(V3.6.5)_PJT명__20151109.xls
#    📊 복사 완료: 1/1개
#
# 📄 [30] 게시판ID: 865507
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865507
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd865507
#    ✅ 첨부파일 1개 발견
#       ✅ 2015년_인건비-원가-판가테이블(20150901)_게시용.xlsx
#    📊 복사 완료: 1/1개
#
# 📄 [31] 게시판ID: 865475
#    원본: C:\Users\LEEJUHWAN\Downloads\2011-01-01~2015-12-31\html\resource\file\brd\865475
#    복사: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments\brd865475
#    ✅ 첨부파일 1개 발견
#       ✅ 고객명_사업명_FP기반예상원가산정(yymmdd).xls
#    📊 복사 완료: 1/1개
#
# ============================================================
# ✅ 처리 완료!
#    - 게시판 타입: cp
#    - 첨부파일 있는 posts: 29개
#    - 총 첨부파일 개수: 29개
#    - 복사된 파일 위치: C:\Users\LEEJUHWAN\Downloads\board_cp_attachments
#    - DB 테이블: board_posts (attaches_json 컬럼 업데이트)
# ============================================================
#
# ✅ DB 연결 종료
